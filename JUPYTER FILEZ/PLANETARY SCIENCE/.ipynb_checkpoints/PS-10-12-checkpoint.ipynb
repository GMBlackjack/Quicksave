# %% [markdown]
# # Planetary Science Selected Problems Volume 4
#
# ## Authors: Gabriel M Steward

# %% [markdown]
# <a id='toc'></a>
#
# # Table of Contents
# $$\label{toc}$$
#
# CHAPTER 10
#
# [Problem 10.1](#P10.1) (Cometary Orbital Dynamics)
#
# [Problem 10.2](#P10.2) (Interstellar Interloper)
#
# [Problem 10.4](#P10.4) (Interstellar Visit Frequency)
#
# [Problem 10.9](#P10.9) (Relative Brightness Objects)
#
# [Problem 10.12](#P10.12) (Thermal Expansion!)
#
# [Problem 10.17](#P10.17) (Species Prevalence)
#
# [Problem 10.23](#P10.23) (Shock Da Comet)
#
# [Problem 10.24](#P10.24) (Dust Grain Distances)
#
# [Problem 10.26](#P10.26) (Houston, We Have Grain Liftoff)
#
# CHAPTER 11
#
# [Problem 11.1](#P11.1) (Rinquation Redundancy Resurgence)
#
# [Problem 11.6](#P11.6) (Ring Gauntlet)
#
# [Problem 11.7](#P11.7) (Ring Around) [Suspected misunderstanding of timescales, continues into 8 and 9 somewhat]
#
# [Problem 11.8](#P11.8) (Ring Construction)
#
# [Problem 11.9](#P11.9) (Saturnian Evolution)
#
# [Problem 11.10](#P11.10) (Ring Doubling Quantities)
#
# [Problem 11.11](#P11.11) (1111)
#
# [Problem 11.12](#P11.12) (Lindblad Resonance) [Chose not to do part b) to completion, tedious]
#
# [Problem 11.14](#P11.14) (CRESTS) [Only part b), other parts are similarly tedious like Problem 11.12]
#
# [Problem 11.20](#P11.20) (You thought we were DONE with probability?)
#
# CHAPTER 12
#
# [Problem 12.7](#P12.7) (Planet Shadows at a Distance)
#
# [Problem 12.8](#P12.8) (Heat Ratios)
#
# [Problem 12.14](#P12.8) (Planets from Limited Data)

# %% [markdown]
# <a id='P10.1'></a>
#
# # Problem 10.1 \[Back to [top](#toc)\]
# $$\label{P10.1}$$

# %% [markdown]
# *Estimate the largest negative value of $1/a_0$ that nongravitational forces are reasonably likely to produce for a comet that is initially in heliocentric orbit and is not subjected to significant planetary perturbations. You may assume that the comet's initial orbit is so eccentric that it may be taken as parabolic and that the comet outgasses 0.1% of its mass with a 10% asymmetry and that this outgassing occurs in a single burst at perihelion, which is at 0.2AU.*

# %% [markdown]
# So, outgassing, let's be very generic and liberal with this since the actual full equation is a nightmare to work with. The actual mass of our comet is so small compared to the sun that it doesn't matter what the total before and after is, it might as well just be M. However, it is important that the ejected amount m is 0.1% of M. Now, by outgassing we outgass in all directions, so the 10% assymetry must refer to the fact that 10% of the "force" this mass imparts is going to go into actually accelerating the comet, so now we're at 0.01$ of actual force involved.
#
# The trick now is what is the acceelration of this dust? If we can get that, we can get the final result. Some searching suggests that some particles move with the Solar Wind. Since we're looking for MAXIMUM possible displacement, let's make these things book at at a solar wind maximum of 750 km/s. At perihelion the tail is flowing away from the sun, so the comet itself is pushed forward. So, overall, the energy change is:
#
# $$ \frac12 0.0001 M (750000)^2 $$
#
# However we do need to consider the direction this energy is being "applied". The push will move it closer to the sun! And would be the same as suddenly increasing the gravity for a moment, which shrinks orbits.
#
# Okay so perhaps the tail isn't the source of our burst. instead, let's have our burst favorably be in the opposite direction of motion, thus boosting the comet forward! However this does mean that our energy calculation no longer works as we don't have a known speed. And if we were to treat it like a rocket we would also need a rough relative speed calculation.
#
# Let's try setting up conservation of momentum.
#
# $$ Mv_i = (M-m)v_1 - mv_2 $$
# $$ \Rightarrow Mv_i = 0.9999Mv_1 - 0.0001Mv_2 $$
# $$ \Rightarrow v_i = 0.9999v_1 - 0.0001v_2 $$
#
# Now we can find $v_i$ from the parabolic trajectory, but the other two not so much, as the two different velocities are independent.
#
# There has to be some way to find the ejection speed of the comet's mateiral... aha! It ejects at 1/2 km/s ISH near 1 AU, but then it expands and speeds up to up to 2km/s. This is Haley's Comet's numbers, so we can probably use them.
#
# Now the velocity of a prabolic orbit is $\sqrt{2GM/r}$, which we can calculate out to be 42.1143 km/s. So the improved speed is now... 42.1187 km/s!
#
# Now we just need to associate this to a hyperbolic orbit. The equation for 1/a is...
#
# $$ 1/a = 2/r-v^2/GM $$
#
# 1/a = -2.79e-15 1/m
#
# Woo-ee that's a small difference. BUUUT it's in inverse meters! We need to convert to inverse AU, which gives us -4.191e-4 1/AU. AS we were expecting values up to -1e-3 this is a perfectly acceptable answer. (In figure 10.3 -0.001 appaers to be the far left of the diagram, and there are no comets there. There are a few at what appear to be -0.00075, but the vast majority are within -0.0005, which is about where our comet lies. A particuarly drastic breakup could cause the few more hyperbolic orbits.)
#
# Keep in mind we were using Halley numbers, which only has 0.6 AU perihelion!

# %% [markdown]
# <a id='P10.2'></a>
#
# # Problem 10.2 \[Back to [top](#toc)\]
# $$\label{P10.2}$$

# %% [markdown]
# *Draw a theoretical histogram of 1/a for interstellar comets. You may assume that the velocity distribution (or, more precisely, the distribution of speed, since direction does not matter) of interstellar comets relative to the Sun at infinity is comparable to that of neighboring stars, which can be approximated by a Maxwellian of mean velocity 30km/s.*
#
# $$ N(v) \propto \frac{v}{30} e^{-(v/30)^2} $$

# %% [markdown]
# So, we won't be making a histogram but rather a smooth density function since that's easier to plot. For instance, here's the density function given above:
#
# ![image.png](attachment:image.png)
#
# What we need is a simimlar thing for 1/a.
#
# Now, we naturally assume all interstellar orbits are hyperbolic, obviously. Since direction is irrelevant let's place them all at one direction. So, fhe hyperbolic equation we used in the previous problem::
#
# $$ 1/a = 2/r-v^2/GM $$
#
# Is a generic one, the r does not have to be closest approach, so we can remove it by taking the limit as it approaches infinity.
#
# $$ 1/a = -v^2/GM $$
#
# Solve for v.
#
# $$ v = \sqrt{-\frac{GM}{a}} $$
#
# This makes the number density a function of 1/a instead, and it must be negative.
#
# $$ N(1/a) = \frac{1}{30} \sqrt{-\frac{GM}{a}} e^{-(\frac{1}{30} \sqrt{-\frac{GM}{a}})^2} $$
#
# Though if we want it to be plottable...
#
# $$ N(x) = \frac{1}{30} \sqrt{-GMx} e^{-(\frac{1}{30} \sqrt{-GMx})^2} $$
#
# GM in this case is for the sun and is 1.327e20. Note that this is in SI standard, so we need to use 30,000 m/s instead of our km/s. Thus our formula is:
#
# $$ N(x) = \frac{1}{30e3} \sqrt{-(1.327e20)x} e^{-(\frac{1}{30e3} \sqrt{-(1.327e20)x})^2} $$
#
# Which we can rather easily generate an image for... ah but the units are not our friend. Also, furthermore, plotting it suggests that the negative inverse axes should get *smaller and smaller* the larger GM is, which makes sense but at the size of GM we have it becomes ludicrously tiny, far smaller than even the solar comets, which makes about as much sense as nothing. The SHAPE is consistent though:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The problem is one of scale, we're actually doing things in SI units here. But really when we want a comparison we want 1/a in AU. This means a division by a factor of 1.496e11
#
# $$ N(x) = \frac{1}{30e3} \sqrt{-(8.87e8)x} e^{-(\frac{1}{30e3} \sqrt{-(8.87e8)x})^2} $$
#
# Which produces
#
# ![image.png](attachment:image.png)
#
# And there we go. These values are almost *all* much larger than even the largest we see of comets, which is 0.001ish. 0.5 is most common here. For the record 30km/s gives us 1.01. Finally it all makes sense, the problem all along was the UNITS AAAAAAAAAAAAA.

# %% [markdown]
# <a id='P10.4'></a>
#
# # Problem 10.4 \[Back to [top](#toc)\]
# $$\label{P10.4}$$
#
# *Estimate the frequency at which we would expect to observe interstellar comets. Assume that the Oort cloud contains 1e12 comets that are large enough to be observable if they were to reach the inner solar system, and that five times as many comets have been ejected from the Solar System over time. Postulate that the number of comets produced and released by a planetary system is proportional to the star's mass and that our Solar System is average in this regard. Furthermore, assume that the density of stellar mass in the solar neighborhood is 0.065 earth masses per cubic parsec. (1 parsec is 3.1e18 cm). The typical velocity of a comet relative to the sun at infinity is comparable to that of neighboring stars, 30km/s. Also assume that a coment must come within 2 AU of the Sun to be visible.*
#
# *a) Neglecting gravitational focusing by the Sun, i.e., approximating the trajectories of the comets by straight lines.*

# %% [markdown]
# Let's ignore the sun itself and just pretend we are trying to hit at disc that is 2 AU in diameter, so we have a "cross sectional area" of 12.566 square AU.
#
# So, let us say that all "ejected" comets are distributed randomly more or less regarldess of which star they came from. The sun has released 5e12. If ejection number is proportional to mass, this allows us to find the constant of proportionality: 1.989e30 = A5e12, the constant A is 3.978e17 kg/comet, or 2.514e-18 comet/kg.
#
# We were considering just using the number of stars of various colors and integrating to get total mass, but rather than that we've just been given the overall density in stellar mass, 0.065 earths per cubic parsec. This is 3.88e23 kg per cubic parsec. Using our constant of poportionality, we end up with 9.754e5 comets per cubic parsec. These are specifically ejected comets spinning around randomly.
#
# If the average speed is 30km/s, every comet will cross the length of the cubic parsec in about 1.033e12 seconds. We could also write this as 32,000 years.
#
# So if 9.754e5 comets cross the length of the cubic parsec in 32,000 years, how many of them hit our circle? Well, this is actually just a case of converting from 12.566 square AU to a square parsec, 2.954e-10. This is 2.881e-4 comets. You heard me, less than *one* every 32,000 years. This means we don't expect the first comet for 111 million years!

# %% [markdown]
# *b) Including gravitaitonal focusing by the Sun, i.e., considering comets to be traveling on hyperbolic orbits around the sun.*

# %% [markdown]
# Okay so this here is going to require finding the cross sectional area of hyperbolic orbits, and the result is that the square AU conversion will change, all other numbers remain constant. This means we need to know the angle of scattering in a hyperbolic orbit that just barely reaches 2AU. This means we're going to need the angle of the hyperbolic asymptote. We have ways to find the semimajor axis a, in fact if we have the same velocity at infinity there's no ambiguity. For 30km/s, a=0.986 AU.
#
# The problem is, a is not sufficient to define the asymptote, we also need something else.
#
# The periapsis distance is given as -a(e-1), which means e is our parameter we can specify. For a "barley scratching" orbit we have e = 3.028 which, yeah, tracks for a highly hyperbolic orbit.
#
# The semi-minor axis (which we will use to characterize the asymptote) is $b = - a\sqrt{e^2-1}$. With our values b=2.19 AU.
#
# Now, with this we are armed to find the "radius of cross section," which can basically be thought of the distance of closest approach by the asymptote. The line can be represented by a slope of |b|/|a|. Our goal is to find the point on this line that is closest to the position of the sun $|a|+r_p$, where $r_p$ is the periapsis distance.
#
# So let's generate a function for this, as we will have to do it again for part c). Our asymptote is $y = |b/a| x$. The function we want though is the distance from any point x to the point $(0,|a|+r_p)$. This distance will always be
#
# $$ \sqrt{(|a|+r_p-x)^2 + y^2} = \sqrt{(|a|+r_p-x)^2 + (|b/a|x)^2} $$
#
# Now as finding the minimum of the square is sufficient, we can get rid of the root.
#
# $$ (|a|+r_p-x)^2 + (|b/a|x)^2 $$
#
# This is what we need to minimize. With constants set to 1, the shape is:
#
# ![image.png](attachment:image.png)
#
# Which we can see *has* a minimum so this should be doable. So we take the derivative:
#
# $$ -2(|a|+r_p-x) + 2(|b/a|^2x) $$
#
# Now the minimum is when the derivative equals zero.
#
# $$ \Rightarrow -|a|-r_p-x + |b/a|^2x = 0$$
# $$ \Rightarrow (|b/a|^2-1)x = |a| + r_p$$
# $$ \Rightarrow x = \frac{|a| + r_p}{|b/a|^2-1}$$
#
# As long as |b| > |a| this produces a positive value. Which is what we have. If |a|>|b| the equation breaks. (Note that |a| = |b| the closest point bisects (0,0) and the point directly above the sun) Fortunately for us our |a| > |b| so we're completely safe!
#
# So running the calculation gives us a distance of... 0.416 AU. Note that this is the distance from the origin, not the sun, the actual distance from the sun here is 2.570 AU.
#
# Which is to say the sun isn't focusing things *very* much in terms of scattering area. But this still increases the area to 20.746 square AU. This is 4.876e-10 square parsecs. This translates to 4.756e-4 comets per 32,000 years. We should see one every 67 million years in this case.

# %% [markdown]
# *c) Repeat parts a) and b) assuming that we can observe all comets that approach to witihn 5 AU of the sun.*

# %% [markdown]
# This is a bit of wishful thinking, comets don't always react at 5 AU, so not all of them will "comet up" at this point. But oh well, let's go ahead and extend the distance.
#
# For part a) this just gives us a cross sectional area of 78.540 square AU, or in square parsecs, 1.846e9. A mere 17 million year wait!
#
# Now if we allow the sun to grab stuff, we need to get ourselves a new b. The closest approach is 5 AU so... b = 5.904 AU. This gives us "x=0.141" which corresponds to a distance of 5.845 AU, thus the cross section is 107.313 square AU, or in square parsecs, 2.522e-9. This reduces the wait time to 13 million years!
#
# Basically we shouldn't expect an extraterrestrial comet ever.
#
# In fact our numbers are so low we're a little suspicious... we *have* seen a single interstellar object, and it passed through *Mercury's* orbit. So clearly these things *do* show up.

# %% [markdown]
# <a id='P10.9'></a>
#
# # Problem 10.9 \[Back to [top](#toc)\]
# $$\label{P10.9}$$

# %% [markdown]
# *An asteroid and a comet have the same apparent brightness while both are at $r_\Delta = 2AU$ and $r_\odot = 3AU.$ At a time later they are both observed at $r_\Delta = 2AU$ and $r_\odot = 2AU$. Which object is brighter and by approximately how much?*

# %% [markdown]
# The comet, obviously, it's far more reflective. Though the "how much" question, well... let's do some thinking.
#
# Okay so there's some complexities here that have now come to light. The actual abledo of comets is very very dark, but this is just the *nucleus*, within the 2-3AU distances the comet's brightness is primarily determined by the coma.
#
# Since the earth distance is the same in both cases, it is irrelevant to the relative brightnesses of the two objects as they both will dissipate $1/r^2$ like everything does.
#
# Turns out we have a relative brightness equation, 10.3 $B \propto \frac{1}{r_\odot^\zeta r_\Delta^2}$. Asteroids have $\zeta=2$ while comets, due to becoming more active closer to the sun, have larger values. The exact value of $\zeta$ appears to be variable for comets, so we shall treat it as a known constant but give it no numbers. WE already discussed the earth distance being irrelevant, so...
#
# $$ A \frac{1}{3^\zeta} = A' \frac{1}{3^2} $$
#
# This is for when they were both at 3 AU. Note the proportionality constant, which is unfortunately not the same for both as then it would require both $\zeta$ values to be the same.
#
# Now, what are the adjustments for each? Well..
#
# $$ A \frac{1}{2^\zeta} $$
# $$ A' \frac{1}{2^2} $$
#
# The asteroid adjusts from 1/9 to 1/4, a factor of 9/4 brighter, so 2.25.
#
# The difference between $1/3^\zeta$ and $1/2^\zeta$ is a bit harder to define.
#
# $$ \frac{3^\zeta}{2^\zeta} $$
#
# So naturally for all $\zeta>2$ this is more than the asteroid. The *exact* value of proportionality between them woudl be
#
# $$ \frac{4}{9}\frac{3^\zeta}{2^\zeta} = \frac{3^{\zeta-2}}{2^{\zeta-2}} $$

# %% [markdown]
# <a id='P10.12'></a>
#
# # Problem 10.12 \[Back to [top](#toc)\]
# $$\label{P10.12}$$

# %% [markdown]
# *At a distance $r_\odot$ = 1 AU, outgassing is dominated by H2O and a comet's surface temperature is 190K. The latent heat of sublimation is $L_s \approx 5e11 erg/mol$. Assume the bond albedo $A_b=0.1$ and the infrared emissivity $\epsilon_{ir} = 0.9.$*
#
# *a) Derive equation 10.6 and use it to determine the gas production rate of this comet.*

# %% [markdown]
# The equation is:
#
# $$ Q \approx \frac{(1.2e18)\pi R^2}{r_{\odot AU}^2} $$
#
# And we are told it was derived with a bond albedo of 0.1, which we are in fact assuming. Q is the gas production rate.
#
# This... is looking to be a pain, because the equation to derive it from is:
#
# $$ (1-A_b) \frac{\mathcal F_\odot e^{-\tau} \pi R^2}{r^2_{\odot AU}} = 4\pi R^2 \epsilon_{ir} \sigma T^4 + Q\frac{L_s}{N_a} + 4\pi R^2 K_T \frac{\partial T}{\partial z} $$
#
# The last term is small for comets and usually ignored, so...
#
# $$ \Rightarrow (1-A_b) \frac{\mathcal F_\odot e^{-\tau} \pi R^2}{r^2_{\odot AU}} = 4\pi R^2 \epsilon_{ir} \sigma T^4 + Q\frac{L_s}{N_a} $$
#
# Solve for Q so we can have some idea what we're actually going for.
#
# $$ \Rightarrow (1-A_b) \frac{\mathcal F_\odot e^{-\tau} \pi R^2}{r^2_{\odot AU}}\frac{N_a}{L_s} - 4\pi R^2 \epsilon_{ir} \sigma T^4\frac{N_a}{L_s} = Q$$

# %% [markdown]
# MOST of what we have here are numbers that are provided or obvious. Those that aren't are R, r, and $\tau$. Of these only $\tau$ is a problem as we need to get rid of it in the final expression. We'll see what happens. first. Just evaluate things...
#
# Man this is a units mess waiting to happen, note how the first term is over AU, but the $\sigma$ constant most definitely is not in terms of AU. This'll be... annoying to be sure.
#
# Bizarrely the units don't seem to match, we have $W/AU^2$ on one and just W on the other. (ignoring the N/L factor for the moment). We can justify this as the AU radius as just a scaling factor for the flux, however unless we can justify ignoring the second term it would demand an AU-based section in the numerator, which is not in what we have provided as the answer by the problem.
#
# Still, we can evaluate with various conversions to get...
#
# $$ \Rightarrow \frac{ 1.640e22 e^{-\tau} \pi R^2}{r^2_{\odot AU}} - \pi R^2 3.204e21 = Q$$
#
# Second term is annoyingly not neglegible, and does not have the radius factor on it. Joy.
#
# Now, what is the optical depth? Google search suggests that at the surface it reaches about 10. So...
#
# $$ \Rightarrow \frac{ 7.446e17 e^{-\tau} \pi R^2}{r^2_{\odot AU}} - \pi R^2 3.204e21 = Q$$
#
# Now we note that the first term is *close* to what we want, possibly just due to an argument over what the optical depth actually is. But in that case, why would we ignore the second MUCH LARGER term? The only thing we can think of is the scaling difference but we can't see how that would change anything if the untis agree. If they don't agree, how are we even adding them...?

# %% [markdown]
# Regardless we can still USE the given version. Rather trivially we end up with
#
# $$ Q \approx (3.770e18) R^2 $$
#
# Note that nowhere are we told what the radius of this comet is, though in part b) we are told it ranges from 1 to 10 km. If we take this we get a range of values:
#
# $$ 3.770e24 < Q < 3.770e26 $$
#
# In molecules per second.

# %% [markdown]
# *b) Calculate the thermal expansion velocity of the gas and compare this to the escape velocity of a typical comet, radius 1-10 km.*

# %% [markdown]
# Thermal expansion velocity is given by the relation:
#
# $$ \frac12 \mu_a m_{amu} v_0^2 = \frac32 kT $$
#
# Which those of us in the know can recognize as a form of the Equipartition Theorem. Just replace the unusual variables with mass and get
#
# $$ v_0^2 = \frac{3kT}{m} $$
#
# The mass in this case is that for water, 2.989e-26 kg. The result is a velocity of 513 m/s. Speedy! Nowhere near enough to escape from EARTH... but what about a comet?
#
# Rather than just looking it up let's actually do it. Consider a comet to be a 10km sphere made out of water, so a total mass of 4.189e15 kg. Escape velocity is $\sqrt{2GM/r}$ as usual, which means... 7.477 m/s. The outgassing *easily* escapes, which is probably why the tail is so *massive*.
#
# This does match what we know, Haley's Comet has an escape velocity of 2 m/s. *two*. Fun.
#
# Granted the gas might not shoot off at directly the right direction, but still 513 is high enough that basically everything escapes. Explains why dust can be dragged away as well.

# %% [markdown]
# <a id='P10.17'></a>
#
# # Problem 10.17 \[Back to [top](#toc)\]
# $$\label{P10.17}$$

# %% [markdown]
# *A comet at a helicocentric distance of 1 AU shows a gas production rate Q = 1e29 molecules per second. The outgassing is dominated by H2O*
#
# *a) Plot the H2O number density as a function of distance from the comet. Assume an outflow velocity of 1 km/s and a lifetime for H2O molecules of 6e4 s.*

# %% [markdown]
# Oh joy this is revealing that I may have gotten half life and mean life confused elsewhere...
#
# Anyway mean life produces $e^{-t/\tau}$, where $\tau$ is our mean life. So we can find molecules remaining in *time*. At the first second we have 1e29, and over time we have $1e29e^{-t/\tau}$
#
# Now the density is going to be fun as we're going to have shells, but we also need a volume-based density. What fun! If we assume time is not an issue and ignore the fact that the first few seconds of emission are obfuscated by the inner coma, we *can* just replace time with physical locaiton x (in km).
#
# $$1e29e^{-x/\tau}$$
#
# This is how many exist in in a "shell" at any given moment. However, that shell is not infinitely thin, as we're not emitting 1e29 particles every instant, but every *second*. So to divide by the volume we need to divide by the volume of a shell that has a "width" equal to 1km--that is, the 1 second it takes for a new set to be produced. However, rather than doing that annoying volume calculation, we can reason out some nature. If there was no decay, the density would go like $1/r^2$, via the surfac3e area $4\pi r^2$. But wait, doesn't this give us a surface density? Well, at an individual shell, the surface density changes so slowly that the surface above and below would have the same surface density. To get a volume density from a bunch of shells, one would just multiply by the scale length: which in this case is just 1! 1km/s! So the volume density and the surface density are interchangeable at any given point. Thus...
#
# $$ \frac NV = \frac{1e29e^{-x/\tau}}{4\pi x^2} $$
#
# Which we can plot. We normalized the initial value to 1 since 1e29 was unweildy.
#
# ![image.png](attachment:image.png)
#
# One will note that this tapers off *really* quickly, in single kilometers. The coma is not very dense. Also note that we diverge at 0--this is because naturally we're emitting from the comet's surface. So the density is going to be eeeeven lower. However the behavior is pretty standard, decaying exponential, nothing to write home about.

# %% [markdown]
# *b) Assume that all H2O molecules dissociate into OH and H, and OH has a lifetime of 1.7e5 s. Plot, according to the Haser model, the OH number density as a function of distance from the comet.*

# %% [markdown]
# I have taken it upon myself to find not only OH, but also H. First of all, let's get equations for the numbers at distances before dividing through by the volumes.
#
# $$ H2O = 1e29e^{-x/\tau}$$
#
# The amount of OH gained every second is the negative derivative of H2O. However, it is *also* decaying based on its current total. This gives us a rather annoying differential equation:
#
# $$(OH)' = -\lambda_2(OH) + \lambda_1(H2O) $$
#
# Second term is growth, which is also (H2O)'. The $\lambda$ values are related to $\tau$, and are actually the inverse, but let's not worry about that right yet.
#
# If we start with zero of OH (or H) initially, we then end up with:
#
# $$ OH = \frac{\lambda_2}{\lambda_2 - \lambda_1} (1e29) (e^{-\lambda_1 t} - e^{-\lambda_2 t}) $$
#
# Which we can convert into $\tau$ form...
#
# $$ OH = \frac{1/\tau_2}{1/\tau_2 - 1/\tau_1} (1e29) (e^{-t/\tau_1} - e^{-t/\tau_2}) $$
#
# And we assume the speed doesn't change so if we want the density we divide by the surface area. We have $\tau$ for OH, and for H it is variable but we will choose the middle value of 1.5e6 s.
#
# AHA! reading up we note that hte OH molecule's speed doesn't change much, but the H molecules will get a whopping *18* km/s. This seems to imply that the entire momentum energy goes into either OH or H, which goes against our assumption that everything dissociates into both. Unless energy is added by dissociation. Regardless, we shall use these values. OH is still the same.
#
# Meanwhile H's density is reduced by a factor of 18 as it's going so fast it literally spreads itself out.
#
# $$ OH = \frac{1}{4\pi x^2}\frac{1/\tau_2}{1/\tau_2 - 1/\tau_1} (1e29) (e^{-x/\tau_1} - e^{-x/\tau_2}) $$
# $$ H = \frac{1}{72\pi x^2}\frac{1/\tau_2}{1/\tau_3 - 1/\tau_1} (1e29) (e^{-x/\tau_1} - e^{-18x/\tau_3}) $$

# %% [markdown]
# And now we go PLOTTING! What fun shall we have today? WHO KNOWS!
#
# The division by the surface are is heavily dominating. How about we examine the total count isntead? The graph struggles with the other way.
#
# ![image-2.png](attachment:image-2.png)
#
# The density changes far too much for this graph to be helpful. So how about instead we compare the total number at any given x? We will note that the H value still needs to be divided by 18 for this, if we actually want to compare the relative values.
#
# ![image-3.png](attachment:image-3.png)
#
# Note that H is so small it's not really visible, but we can see it if we zoom in a bit:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# *c) How, qualitatively, does the $N_d(r)$ differ in the vectorial model from that given by the HAser model? Describe approximately using a graph and associated text.*

# %% [markdown]
# HILARIOUS! We re-derived the Haser model without realizing it (for OH).
#
# $$ N_d(r) = \frac{Q}{4\pi r^2 v_d} \frac{R_d}{R_d-R_p} (e^{-r/R_d} - e^{-r/R_p}) $$
#
# Absolutely hilarious. The model's only real difference is that we haven't simplified the mean lifetime fractions, though apparently in can be. (And we attempted to use different velocities with H, though that was not part of the problem so...)

# %% [markdown]
# <a id='P10.23'></a>
#
# # Problem 10.23 \[Back to [top](#toc)\]
# $$\label{P10.23}$$

# %% [markdown]
# *Calculate approximately the standoff distance of the bow shock of Halley's comet at 0.9 AU. Assume an icy comet with a production rate of 1e30 molecules a second, a solar wind density of 5 protons per cubic centimeter, and a velocity of 400 km/s. Estimate the ionization rate from molecular lifetimes.*

# %% [markdown]
# The bow shock radius is
#
# $$ R = \frac{Q m \alpha (\gamma^2-1)}{4\pi v_0 \rho_{sw} v_{sw}} $$

# %% [markdown]
# So, what values are what? Well for magnetic systems $\gamma = 2$ and the molecular mass is m--this is the molecular mass of the "neutrals" being outgassed so it would be H2O primarily. $\alpha$ is the ionization rate which we will have to calculate later. Q is given for Halley, 1e30 molecules a second. The "sw" values are for hte solar wind which are provided (or easily able to be obtained).
#
# So we need $v_0$ (the outgassing speed) and $\alpha$ currently. The speed we found in an earlier problem via:
#
# $$ v_0^2 = \frac{3kT}{m} $$
#
# Problem is what is the temperature of our comet at 0.9 AU? Equilibrium temperature is highly unlikely--ah but we know 500 m/s near 1 AU is common, so for our estimate we can keep that and not worry further. WHich means... what is the ionization rate?
#
# Well, as the primary constituent is water with a lifetime of 6e4 seconds, we need to turn this into ionizations per second. The *real* question then is by what metric is the ionization rate measured? Is it with respect to all molecules in the entire comet, or just at the radius where we want to put the bow shock?
#
# A quick lookup implies it is *per atom*, so what is the rate of ionization for a single atom? Well, the mean lifetime is 6e4 seconds, so just invert this. An ionization is expected once per 6e4 seconds, or 1.667e-5 1/s.
#
# Before we begin convert protons per cubic centimeter to kilograms per cubic meter: 8.303e-21. And the molecular mass of water: 2.989e-26 kg.
#
# The RESULT is 7.163e10m, or 7.163e7 km. Meanwhile the answer provided by the book is 1e6. Given how many assumptions are inherent in this mess (perhaps the most dramatic being that water is the only constituent of the emissions and that secondary ionization effects don't occur), we consider being only an order of magnitude off to be fine.

# %% [markdown]
# <a id='P10.24'></a>
#
# # Problem 10.24 \[Back to [top](#toc)\]
# $$\label{P10.24}$$

# %% [markdown]
# *Comet X is on a nearly parabolic orbit with a perihelion at 0.5 AU. Calculate the (generalized) eccentricity of grains released form near perihelion as a function of $\beta$. Give a formula for the separation between the grains and the nucleus as a function of $\beta$ and t that is valid for the first few days following release.*

# %% [markdown]
# Okay, so at 1 AU we generally have 500m/s release speeds. However at 0.5 AU we will have *four times* the avilable energy. Using $\frac12mv_0^2$ as the base, we find that our new speed will be... 1000 m/s, or a km/s. That sure makes things simple.
#
# Keep in mind that this is km/s relative to the comet.
#
# So, the comet is on a parabolic orbit. Due to the increase in speed literally none of these grains are going to stay on the same parabolic trajectory, however some will enter into wide ellipses while others will shoot off into hyperbolic nonsense space. It all depends on the angle of emission to determine which ones will go which way. The eccentricity can actually be calculated pretty simply, but we have a question... what is $\beta?$.
#
# Oh it's just the angle from the sun. Which we were already going to use. Ehe...
#
# ANYWAY the eccentricity of a parabolic orbit is precisely 1. We can identify that the particles shot out along the orbital plane will do specific things: one shot forward has e>1, one shot backward has e<1. Somewhere in the middle we hit the point where we remain on a parabolic orbit, but this point will not be directly pointing at the sun as that one necessarily changes the situation. What fun.
#
# (Note that we are not considering things ejected *up* or *down* from the plane of the orbit).
#
# We had a thought: perhaps we do not need orbital shenanigans and can instead just quantify everything by the *energy* of the orbits. Of course that depends on figuring out how fast our comet is going at perihelion. Turns out parabolic trajectories are neat in that regard:
#
# $$ v = \sqrt{\frac{GM}{r}} $$
#
# So at the time we care about, our comet is moving 42km/s. The energy of the orbit is proportional to the square, so 1773 is our factor to compare to. If we are higher, we transfer into hyperbolic orbits, and if we are lower, we transfer into elliptical orbits. For orientation, assume sun lies on the x axis, comet is moving in -y, and angle is positive counterclockwise.
#
# $$ v = \sqrt{ (42 - sin\theta)^2 + sin^2\theta } $$
#
# This should have some curious graphical behavior!
#
# ![image.png](attachment:image.png)
#
# One might think "hey, that's just oscillating around 42 km/s, shouldn't there be a change?" Well, there is, it's just absurdly tiny.
#
# ![image-2.png](attachment:image-2.png)
#
# Which means that we might as well ignore any perpendicular contributions to the orbit, while there is a slight change when a particle is ejected directly at or directly away from the sun, it's sure not much of one. Which means that forward ejected particles enter hyperbolic trajectories and backward ejected ones enter elliptical trajectories. The potential energies at this point are the same, only the kinetics change.
#
# The question now is, of course, how do we convert this into a direct determination of eccentricity? Well, do we have a relation that correlates eccentricity to energy?
#
# $$ e = \sqrt{1 + \frac{2 \epsilon h^2}{G^2M^2}} $$
#
# And we can actually find all these quantities. h is the is the angular momentum divided by the reduced mass, and $\epsilon$ is the specific orbital energy (total) divided by reduced mass. Now the reduced mass, when something is really huge, is just the smaller body's mass, that is "m" of either the comet or the particle. Angular momentum is mvr, and since h is mvr/m, well, now it's just vr, both values which we have.
#
# The standard orbital energy can be given in many ways but the one we want to use is $v^2/2 - GM/r$, as we have all the values in it. Thus...
#
# $$ e = \sqrt{1 + \frac{2 \left( \frac{v^2}{2} - \frac{GM}{r}\right) v^2 r^2}{G^2M^2}} $$

# %% [markdown]
# The velocity v is the part that depends on angle.
#
# $$ v = \sqrt{ (42 - sin\theta)^2 + sin^2\theta } $$
#
# Of course as we found out it might as well just be
#
# $$ v = 42 - sin\theta  km/s$$
#
# Which means we satisfy the first criteria of this problem, even if it is an ugly expression.
#
# However, we *now* need an expression for the distance the emitted dust particles have from the comet. We note that at 0.5AU is comparable to Mercury's orbit, which lasts 88 days, so a *few* days of accuracy means we don't need to plot exact results based on trajectories and can instead think of the paths as parts of circles -- larger distances from the sun require larger times to sweep out the same area, after all. Because of this over the first few days things that were released directly ahead of or directly behind the comet will experience no drift at all and just have distance markers of d = vt = 1(km/s)t. These correspond to the angles of $\pi/2$ and $3\pi/2$. However, particles released at an *angle* will lag further and further behind the more distant they become. The length element for angular motion is rd$\theta$, after all.
#
# First, we split the motion up into two parts. Tangential and perpendicular.
#
# $$d^2 = (vtsin\theta)^2 + (vtcos\theta)^2$$
#
# Curiuosly, while the sine portion is what's taking us further away radially, it will provide an adjustment to the *cosine* portion in the form of backward drift. We find out how much we adjust by treating the paths as "on circles" that are really close to each other. The length element of the comet would be rd$\theta$ but the length element of the particle would be (r+dr)d$\theta$. This creates a factor of $\frac{r}{r+dr}$ enhancement to the tangential direction. Or...
#
# $$d^2 = (vtsin\theta\frac{r}{r + vtcos\theta})^2 + (vtcos\theta)^2$$
#
# And *this* is our distance correlation with time, good gravy...
#
# Anyway it produces a rather interesting graph of relative displacements.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# So the first hump below the line represents particles that are shot backward but also *inward*, so they have a tendencey to drift *forward* while nonetheless they were shot away, so they stick closer to the comet than they otherwise would. The other two humps are ejections into orbits further out, so they drift further away faster. Then we return to ones launched closer to the sun.
#
# Note that if we did this more accuratley, it would not be so symmetric and the front and back humps would show clear differences.
#
# Note that this plot is plotting $d^2$ so the scale is a bit funky. Time was set to 0.7 for this picture.

# %% [markdown]
# <a id='P10.26'></a>
#
# # Problem 10.26 \[Back to [top](#toc)\]
# $$\label{P10.26}$$

# %% [markdown]
# *Calculate the size of the largest icy particle that can be released by gas drag from the surface of an icy comet with a radius of 1km at the heliocentric distances of 3, 1, and 0.3. List and explain all your assumptions.*

# %% [markdown]
# Well, we know how much energy is available to launch individual molecules.
#
# $$ \frac12 m v_0^2 = \frac32kT $$
# $$ v_0^2 = \frac{3kT}{m} $$
#
# A very crude estimate would be simply to replace the m of one molecule with M for a whole particle, limiting $v_0$ to the (very low) escape velocity of the comet. The comet's mass to be 4.189e12 kg for the 1km radius case (we've done the basic calculation in previous problems to boot, this ain't the hard part). From this we get an escape velocity of 0.7m/s. So we do *not* need to be going very fast, and the individual molecules have orders of 100s of m/s so this'll easily be able to pull up some big ones.
#
# The hard part is limiting the temperature T. But there is another issue: if sublimation is providing the energy, the energy moving one molecule is not the one interacting with our large grain. In fact an entire cross-sectional area of water molecules could be lifting the grain. The amount of water molecules is obviously proportional to $\pi r^2$, with r the radius of the grain, but what is the density of water molecules?
#
# Well, quick lookup tells us that there are 3.3e22 molecules of water in a cubic centimeter, which means that a square centimeter would "have" 1.029e15 water molecules. (3D to 2D is always awkward but there are so many atoms we apply the continuum approximation here). Now this means that the total available energy is not $\frac32kT$ but $\frac32kT(1.029e15)\pi r^2$, as each water molecule can push into the larger grain. Naturally we are assuming perfect transfer of energy here, which is unlikely, but we're trying to think of the largest *possible* particle that can be released. NOTE: the equaiton we provided is for square cm. If we want square meters, that's $\frac32kT(1.029e19)\pi r^2$.
#
# The mass of a grain of radius r made of ice is simply $1000 \frac43 \pi r^3 = 4189 r^3 kg$. This is our mass m.
#
# So our adjusted relation is...
#
# $$ v_0^2 = \frac{3kT}{4189 r^3}(1.029e19) $$
#
# We can evaluate many things here.
#
# $$ 0.49 = \frac{T}{r^3}(1.017e-7) $$
#
# We can see here that r is going to be pretty small, but it *is* a grain what were we expecting? Now all that remains is to characterize T, which changes based on how far we are from the sun. HOW it changes is... questionable... as equilibrium temperature is highly suspect.
#
# We can do 1 AU though, as we have a value of 190K for that. We get a value of 3.4 cm. We seem to recall the largest grains in comet tails being of centimeter size, so the fact that ideal conditions produce such a size is a good sign.

# %% [markdown]
# So, here's a thought, perhaps we don't have to actually calculate what the T of the comets are at different distances, but rather we consider the fact that the incoming energy from the sun scales with $1/r^2$ and thus avialable comet energy should do the same. So 0.3 AU provides a 11x bonus while 3 is a 1/9 reduction. If we go by this, we can just multiply by the factor.
#
# Following this, at 0.3 AU we have 7.6 cm radius.
#
# At 3 AU we have 1.6 cm.
#
# What we effectively did here was multiply the 1.029e19 multiplicity factor by these scales, indicating that each individual water molecule had less energy to work with. We do note that this will not quite be accurate: the more a comet develops the more its coma blocks incoming sunlight from reaching the surface, and so the increase wouldn't be quite as large for 0.3 AU, and consequently at 3 AU the decrease also wouldn't have been as large.
#
# Fact remains, centimeter sized grains all around. The most massive things to lift off!

# %% [markdown]
# <a id='P11.1'></a>
#
# # Problem 11.1 \[Back to [top](#toc)\]
# $$\label{P11.1}$$
#
# *a) Derive equation 11.7 from 11.6. Hint: recall that the analysis assumes that the planet is spherical.*

# %% [markdown]
# Our goal is
#
# $$ \frac{a}{R_p} = 3^{1/3} (\frac{\rho_p}{\rho_s})^{1/3} $$
#
# This is the roche limit where the tidal forces are just balanced.
#
# 11.6 is
#
# $$ \frac{GM_s}{R_s^2} = \frac{3GM_pR_s}{a^3} $$
#
# Now, we need to get densities from masses. $\rho = M/V$ so we can change everything to::
#
# $$ \frac{G\rho_s V_s}{R_s^2} = \frac{3G\rho_p V_pR_s}{a^3} $$
#
# Now the volumes are $4/3 \pi r^3$. The leading constants cancel out, but the radii do not. Also while we're at it we can cancel out G.
#
# $$ \frac{\rho_s R_s^3}{R_s^2} = \frac{3\rho_p R_p^3 R_s}{a^3} $$
# $$ \rho_s = \frac{3\rho_p R_p^3}{a^3} $$
# $$ \frac{a^3}{R_p^3} = \frac{3\rho_p}{\rho_s} $$
# $$ \frac{a}{R_p} = \left(\frac{3\rho_p}{\rho_s}\right)^{1/3} $$
#
# And yeah this is what we wanted.

# %% [markdown]
# *b) Derive equaiton 11.7 from equation 2.22*

# %% [markdown]
# Making me go dig things up are ya? All right, I'll play along, what do we got?
#
# $$ R_H = \left( \frac{M_s}{3(M_p+M_s)} \right)^{1/3} a $$
#
# This is the hill sphere, aka, the area in which a planet's / moon's gravity dominates. Clearly when the hill sphere is equal to the radius of the *moon*, we then have a point where it's gravity doesn't even dominate on its own surface, and we have the roche limit.
#
# $$ R_s = \left( \frac{M_s}{3(M_p+M_s)} \right)^{1/3} a $$
#
# Flip the term across and replace it with the volume/density version, again canceling out the constants.
#
# $$ \left(\frac{3(\rho_p V_p + \rho_s V_s)}{\rho_s V_s}\right)^{1/3} = \frac{a}{R_s} $$
# $$ \Rightarrow \frac{3(\rho_p V_p)}{\rho_s V_s} + 3 = \frac{a^3}{R_s^3} $$
#
# Turn volujmes into radii.
#
# $$ \Rightarrow \frac{3(\rho_p R_p^3)}{\rho_s R_s^3} + 3 = \frac{a^3}{R_s^3} $$
# $$ \Rightarrow \frac{3\rho_p}{\rho_s} + \frac{R_s^3}{R_p^3} 3 = \frac{a^3}{R_p^3} $$

# %% [markdown]
# Now, uh, there's this awkward 3 right there. However, it is neglegible for any small moons. Thus...
#
# $$ \Rightarrow \frac{3\rho_p}{\rho_s} = \frac{a^3}{R_p^3} $$
#
# Which we will recognize from the previous part. Done!

# %% [markdown]
# <a id='P11.6'></a>
#
# # Problem 11.6 \[Back to [top](#toc)\]
# $$\label{P11.6}$$
#
# *If a ring has optical depth $\tau$ then using the geometrical optics approximation, a photon traveling perpendicular to the ring plane has a probability of $e^{-\tau}$ of passing through the rings without colliding with a ring particle. For this problem, you may assume that the ring particles are well separated and that the positions of their centers are uncorrelated.*
#
# *a) What fraction of light approaching the rings at an angle $\theta$ to the ring plane will pass through the rings without colliding with a particle?*

# %% [markdown]
# So. That depends on how *thick* the ring is. So let's do it in generality, that the ring is d thick and l wide. Then an angle cutting through it has a minimum of d and a maximum of l (when l >> d), strictly speaking the diagonal is the largest length in that case). However there's a lot of complexities when dealing with a finite rectangle, and future problems indicate we should have been treating the ring as an infinite slab since basically nothing comes at it from dead on. In THAT case we can rely on tangent functions:
#
# $$ D^2 = d^2 + d^2 tan\theta $$
#
# Roughly. The optical depth is for a distance d, so...
#
# $$ P = e^{-\tau D/d} $$
#
# Naturally the larger D gets than d, the more ridiculously tiny the probability becomes.

# %% [markdown]
# *b) The cross-section of a ring particle to collisions with other ring particles is larger than its cross section for photons. Assuming all ring particles are of equal size, what is the probability that a ring particle moving normal to the ring plane woudl pass through the rings without a collision?*

# %% [markdown]
# Yeah, photons can be modeled as points, but dust particles cannot. The atual cross sectional area is that of a circle with 2R, so the area goes from $\pi R^2$ to $4\pi R^2$, so collisions are four times as likely.
#
# So the probability of colliding is 1-P. The new probability of colliding is 4-4P, where P is the original probability of getting through unscathed. 1 minus THIS is 4P - 3, which should be the probability of making it through without colliding.
#
# $$ 4e^{-\tau D/d} - 3 $$
#
# Naturally only works when P<1 but also P>3/4, which makes sense because at that point a 4x change would become guaranteed to hit.
#
# Note: this does ignore the fact that particle overlap sometimes means that a 4x increase in individual area does not result in a 4x overall increase. This is unlikely to matter for ring particles though.
#
# Extra Note: for SATURN'S rings though it probably will, given that they are thick. Hmmmm.

# %% [markdown]
# Though, consider the mean free path. l = $1/\sigma n$. n, the particle density, does not change, and the effective cross section increases by a factor of 4. Thus, the new mean free path is 1/4 the original, but the distance traveled remains the same. Thus, the new probability is:
#
# $$e^{-4\tau D/d}$$

# %% [markdown]
# *c) On average, how many ring particles does a line perpendicular to the ring plane pass through?*

# %% [markdown]
# IGNORING all this probability nonsense, let's just think of it like this:
#
# the mean free path is how long a particle travels before hitting another one.
#
# The optical depth is equal to the total distance divided by the mean free path.
#
# This means that hte optical depth *IS* the expectaiton value for how many particles we expect to pass through. Neat!
#
# Thus the number of particles a line will hit is $\tau$. Tah-dah.

# %% [markdown]
# *d) On average, how many ring particles does a particle passing normal to the ring plane collide with? (As ring particles on Keplerian orbits pass through the ring plane twice per orbit, two times your result is a good estimate for the number of collisions per orbit of a particle in a sparse ring. THe in-plane component of the particles' random velocities increases the collision frequency by a small factor, the value of which depends upon the ratio of horizontal to vertical velocity dispersion. For a ring that is thin and massive enough, local self-gravity can increase the vertical frequency of particle orbits, and combined with the gravitaitonal pull of individual particles, greatly increase particle collision frequency.)*

# %% [markdown]
# Since the answer IS the optical depth, we just have $4\tau$. While the chances of making it through may not be scaled by 4, the number of collisions is! Which makes sense, since the 4x area change applies to individual particles, so each particle has 4x more chance to get hit, and thus 4x more particles WILL get hit. Tah-dah!

# %% [markdown]
# <a id='P11.7'></a>
#
# # Problem 11.7 \[Back to [top](#toc)\]
# $$\label{P11.7}$$
#
# *a) Calculate the time necessary for Kepler shear to spread rings with the following parameters over 360 degrees in longitude*
#
# *i) Width 1km orbit 80000 km from Saturn*
#
# *ii) Width 100km orbit 80000 km from Saturn*
#
# *iii) Width 1 km orbit 12000 km from Saturn*
#
# *iv) Width 2km orbit 63000 km from Neptune*

# %% [markdown]
# So, Keplerian shear took a while to *find* out what it was, but it's just the different sped things are rotating at differnet sides. So basically we're asking how long it takes for the inner ring to meet back up with the outer ring, we think. It's best to imagine this not as a ring, but as a line of particles extending from the inner radius to the outer radius. They all orbit but spread out in a spiral (similar to the comet tail). We start at t=0 with them all lined up. When is the outer ring lined up with the inner ring once again?
#
# To do this, we can define a coordinate system where the *outer* ring particle is stationary, and the inner one has to make one full circle to get anywhere. Setting this up depends on finding the angular velocities of both the inner and the outer. Angular velocity can be found from the actual velocity $v = \sqrt{GM/r}$. vt is how far we've gone, and in terms of fractional portion of the orbit it's $vt/2\pi r$. To get an angle multiply by $2\pi$, and thus the angular position is vt/r, or more simply the angular velocity is v/r. $\sqrt{GM}/r^{3/2}$ This is the angular speed. So the RELATIVE angular speed is
#
# $$ \sqrt{GM}\left( \frac{1}{r_1^{3/2}} - \frac{1}{r_2^{3/2}}\right)$$
#
# Inner naturally moves faster so we place it first. So, over time this is...
#
# $$ \sqrt{GM}t\left( \frac{1}{r_1^{3/2}} - \frac{1}{r_2^{3/2}}\right) = 2\pi$$
#
# Note that we want it to equal $2\pi$ in order to find where they meet up the time *after* the initial t=0.
#
# (Irony: we managed to find this equation earlier via incorrect logic. Fun.)
#
# $$ t = \frac{2\pi}{\sqrt{GM}} \frac{1}{\left( \frac{1}{r_1^{3/2}} - \frac{1}{r_2^{3/2}}\right)}$$
#
# Which will work for *completley general* systems. But the problem wants us to find specifics, so all right, might as well. Treat the inner radius as the distance from Saturn (or whatever planet).

# %% [markdown]
# Gravitational parameter for Saturn is 3.793e16. For i) Calculating it out we get 1.23e9 s. This is 39 years. Sensible, when things are close together the time to meetup is long.
#
# For ii) it's 1.23e7 s which is 0.39 years. Shuffles a lot quicker.
#
# Not gonna bother doing the other two, I can already tell you how it changes. At a closer orbit the changes due to small variations are larger (Due to the power dependencies on the radius), so it'll be faster than i) but slower than ii).
#
# As for neptune, it only changes M. A decrease in M actually increases the overall time. As for the specifics, not going to bother.

# %% [markdown]
# *b) Calculate the radial diffusion time for the doubling of the widths of the rings in part a) assuming a viscosity of $v_v = 100cm^2/s$. How do these times vary with viscocity? (give the functional form)*

# %% [markdown]
# $$t_d=l^2/v_v$$

# %% [markdown]
# This is the diffusion timescale. As for how this relates to doubling, uh, is this a half life? A mean life?
#
# It appears to be the timescale over which the rings entirely dissipate. And, like, that's great and all but how are we supposed to tell what part of it gets to be doubled? The timescale notably doesn't care about gravity or planet or anything, just the width of the ring. Note that increasing the length increases the time to diffusion.
#
# Well, *whatever* is being measured, at the very least we can use it to compare things relatively. The width of the ring is all that defines it (aside from the viscocity) so we have:
#
# i) 1e7 s
#
# ii) 1e12 s
#
# iii) 1e7 s
#
# iv) 4e8 s
#
# These are hte diffusion timescales, *not* the doubling times. But the textbook doesn't explain how exactly this equation for diffusion was even calculated, and lookups imply diffusion time is the time it takes to return to equilibrium, which if we're talking about expansion then it'll be when the rings break up fully. So the doubling time should certainly be *less* than this for each category. And yet... note that the lowest of these times is less than a year. So clearly we don't understand what the diffusion time actually measures, as complete dissipation should be much larger than that. Except our rings are rather small, and the equaiton *Does* give huge values if we plug in the values for Saturn's rings.
#
# So maybe it's just the timescale of change we care about, not specifically doubling? I don't know.
#
# We later determined that the doubling time would be half the diffusion scale. This is because the diffusion scale is essentially the time it takes particles to move from one end of the ring to the other, so naturally particles leave the edges at similar rates, thus since we extend from both ends, to double the width you use half the time scale. Are we sure this is the right interpretation? No. Not at all.

# %% [markdown]
# *c) Compare your results in parts a) and b), and comment on the observations that rings are generally observed to vary much more substantially with radius than with longitude.*

# %% [markdown]
# So, here's the thing. For a) we noted that larger rings shuffled a lot faster than smaller ones. However for b) the timescale for larger rings is longer than smaller ones. There's a reversal here.
#
# This makes some sense. The angular distribution shuffles quicker for larger rings due to the difference in orbits from one end to the other, but the radial distribution has further to *go* and is held together more. Which means for large rings we are highly unlikely to see angular incongruencies, but radial ones won't diffuse away. MEANWHILE, tiny insignificant rings are the opposite: clumps will remain in them but they can be radially mixed quickly. WE can think of this as an inherent difference between the circumfernece and the width. If the circumference is much larger than the width, the width evens out first, but there comes a point where these two properties switch.
#
# We note that Saturn's rings are *definitely* in the category where they cycle around and get shufflede, but show radial differences that are heavy. This might have something to do with Saturn's rings being *much* larger than any of the ones shown here--100km? Give me a break, try 60000 km width.
#
# Now, we fully admit this problem has shown that we are not really very good with the precise definitions of mixing and timescales. We think the textbook should have described this but it really doesn't appear to anywhere, so... eh?

# %% [markdown]
# <a id='P11.8'></a>
#
# # Problem 11.8 \[Back to [top](#toc)\]
# $$\label{P11.8}$$

# %% [markdown]
# *Consider the situation in which a small moon on an eccentric and inclined orbit near Roche's limit gets disrupted by a hypervelocity impact. The debris is initially quite localized, and has a velocity dispersion small comapred to its orbital velocity. Using the results of the previous problem, describe the subsequent evolution of the debris swarm.*

# %% [markdown]
# Assuming we understand correctly, the key here is "velocity dispersion small compared to its orbital velocity." This makes this easy to explain. The dispersion of the particles relative to each other in the radial direction is going to be slow while everything moving around the planet will go much quicker. So, we start with a localized ball of dust, however this ball of dust quickly spreads out into a spiral due to the quick orbital motion. The spiral will wind tighter and tighter, until it's basically impossible to tell it's a spiral and it's a ring. Since the radial diffusion is so slow we can end up with things like gaps or radial variations, since variations that existed in the original object will be spread out in long streaks. Now, over time at this point the ring will start to widen and the variations in the radial direciton will smooth out.
#
# This seems to be the basic idea here. Will admit, textbook isn't exactly clear so I'll definitely be doing some of my own research.

# %% [markdown]
# <a id='P11.9'></a>
#
# # Problem 11.9 \[Back to [top](#toc)\]
# $$\label{P11.9}$$

# %% [markdown]
# *Assume that an isolated ringlet of width $\Delta r$ = 20km, full thickness 2H = 2$c_v /\mu=20m$, and optical depth 1 is in orbit 100,000 km away from Saturn's center at a time t=0. The symbols $c_v$ and $\mu$ represent the velocity dispersion and vertical frequency, respectively, and $\mu \approx n$. What is the approximate width of the ring at t=1e3 years? at t=1e8 years?*
#
# *You should use the viscocity formula given by equation 11.11 and the diffusion relationship*
#
# $$ (\Delta r(t))^2 = (\Delta r(0))^2 + v_v t $$
#
# *You may make any plausible assumption about the time evolution of H and $\tau$. (Choose somethign convenient and justify it). Quote your answer in simple units.*

# %% [markdown]
# First of all we can key H and $\tau$ to the width, which we shall call w. Hw = const, as it is the cross-sectional area of the rings, so whatever the initial value of H and w are we can use to set this constant and then H = w(const). Meanwhile the optical depth is $\tau = H / H_0$, that is the fraction of the original thickness.
#
# Might as well find the constant. H=10m, w=20,000m, so 200,000 square meters is our scaling constant. And so... H = 200,000/w, and $\tau = 200,000/(H_0 w) $. Now everything is a function of w, which is what we wanted to find anyway. One may argue that H should be 2H, but that doesn't change $\tau$ as the divisions would be on both ends of the ratio, and H itself is still the same. Basically, it doesn't change anything.
#
# Equation 11.11 is
#
# $$ v_v \approx \frac{c_v^2}{2\mu} \left( \frac{\tau}{1+\tau^2} \right) \approx \frac{c_v^2}{2n} \left( \frac{\tau}{1+\tau^2} \right)  $$
#
# So. Question. Waht is n? Ah, the angular velocity, or $n^2 = GM/r^3$.

# %% [markdown]
# Since the ring is thin compared to the orbital distance, we can treat the radius r as constant: 100,000km. From that we get n=1.948e-4. From this we can vind $c_v$ via the provided ratio, $c_v = 0.00194$. So *now* we have the viscocity, $v_v = 0.00487$.Now, what are the units here, we should ask? Well, everything is in SI units, but the traditional viscosity is in square centimeters per second, so 48.689 $cm^2/s$
#
# From THAT we can calculate the diffusion scale time. Turns out to be 8.215e10 s. Which is sensible, it's on the same order as the timescales we calculated in Problem 11.8.
#
# THe issue though is we *still* don't know how this relates to the actual *size* of the rings. Is it the doubling time? If so, then we double in size every 2605 years. Of course as the width increases we increase the speed at which we increase if we calculate it again... Without knowing specifics I can't say what exactly will happen at 1e3 or 1e8 years, though given how large 1e8 is I'd say at that point the rings would be so large they have to have dissipated.
#
# seriously this all could be explained better.

# %% [markdown]
# Okay so we're going to make a *Basic* assumption about the diffusion time: it is the time it takes for particles to move across the width of the ring, from one end to the other. We can assume for small rings that a particle that crosses a ring means there are particles that move that distance inward and that distance outward. So, really, the time measures how long it takes for things to move in and, after one time scale the width has actually tripled, but the doubling would happen after *half* a time scale.
#
# AS the time scale is 8.214e10 s or 2605 years, we can assume constant speed to get a width increase over time.
#
# $$ w = w_0 + \frac{2t}{2605}w_0 $$
#
# So at 1e3 years we have 35.355 km width. Not too much growth. However at 1e8 years, hoo boy, 1.73e6 km. For the record Saturn's rings are only 1e4 km wide, clearly these rings have dissipated, diffusing too much.
#
# That said, we do note that as the ring expands, lots of the assumptions we made will start to break down. But do we really have to hold to that?

# %% [markdown]
# <a id='P11.10'></a>
#
# # Problem 11.10 \[Back to [top](#toc)\]
# $$\label{P11.10}$$

# %% [markdown]
# *Assume that the differential size distribution of particles in a planetary ring is given by a power law over a finite range (eq 11.17).*
#
# *a) Compute the critical values of $\zeta$ for which equal amounts of i) mass and ii) surface area are presented by particles in each factor of two interval in radius. For larger $\zeta$ (steeper distributions), most of the mass or surface area is contained in small particles, whereas for smaller $\zeta$ most is in the largest bodies in the distribution. Hint: this problem requires you to integrate over the size distribution.*

# %% [markdown]
# The equation in question is
#
# $$ N(R) dR = \frac{N_o}{R_o} \left( \frac{R}{R_o} \right)^{-\zeta} dR (R_{min} < R < R_{max}) $$

# %% [markdown]
# So let's integrate both sides.
#
# $$ N_{total} = \frac{N_o}{R_0} \int_{R_{min}}^{R_{max}} \left( \frac{R}{R_o} \right)^{-\zeta} dR $$
# $$ N_{total} = \frac{N_o}{R_0} \left[ \frac{-1}{R_o(\zeta - 1)} \left( \frac{R}{R_o} \right)^{-\zeta+1} \right]_{R_{min}}^{R_{max}} $$
# $$ N_{total} = \frac{N_o}{R_0} \frac{-1}{R_o^{-\zeta}(\zeta - 1)} \left( R_{max}^{-\zeta+1}  - R_{min}^{-\zeta+1}  \right) $$

# %% [markdown]
# What we have here tells us the particle *number.* UUUUNfortunatley, the particle NUMBER is not the MASS or the SURFACE AREA. So return to the differnetial form and find the versions that do THAT.
#
# $$ M(R) dR = \rho \frac43 \pi R^3 \frac{N_o}{R_o} \left( \frac{R}{R_o} \right)^{-\zeta} dR (R_{min} < R < R_{max}) $$
# $$ SA(R) dR = 4 \pi R^2 \frac{N_o}{R_o} \left( \frac{R}{R_o} \right)^{-\zeta} dR (R_{min} < R < R_{max}) $$
#
# These integrals take similar but not identical forms to the pure numbers game.
#
# $$ M_{total} = \rho \frac43 \pi \frac{N_o}{R_0} \frac{-1}{R_o^{-\zeta}(\zeta - 4)} \left( R_{max}^{-\zeta+4} - R_{min}^{-\zeta+4} \right) $$
# $$ SA_{total} = 4 \pi \frac{N_o}{R_0} \frac{-1}{R_o^{-\zeta}(\zeta - 3)} \left( R_{max}^{-\zeta+3} - R_{min}^{-\zeta+3} \right) $$

# %% [markdown]
# We note that the constants out front don't help us scale anything, so we can use the proportionality instead.
#
# $$ M_{total} \propto \left( R_{max}^{-\zeta+4} - R_{min}^{-\zeta+4} \right) $$
# $$ SA_{total} \propto \left( R_{max}^{-\zeta+3} - R_{min}^{-\zeta+3} \right) $$
#
# So now what we need to do is use radiuses that double from 1 to 2 and then 2 to 4 and find out what value of $\zeta$ keeps this doubling identical no matter what. Declare an arbitrary value R, and then set the two different doubligns equal.
#
# Do mass first:
#
# $$ \left( (2R)^{-\zeta+4} - R^{-\zeta+4} \right) = \left( (4R)^{-\zeta+4} - (2R)^{-\zeta+4} \right) $$
# $$ \Rightarrow \left( 2^{-\zeta+4}R^{-\zeta+4} - R^{-\zeta+4} \right) = \left( 4^{-\zeta+4}R^{-\zeta+4} - 2^{-\zeta+4}R^{-\zeta+4} \right) $$
# $$ \Rightarrow 2^{-\zeta+4} - 1  = 4^{-\zeta+4}- 2^{-\zeta+4} $$
# $$ \Rightarrow 2(2^{-\zeta+4}) - 1  = 4^{-\zeta+4} $$
# $$ \Rightarrow 2^{-\zeta+5} - 1  = 2^{-2\zeta+8} $$
# $$ \Rightarrow 2^{-\zeta+6} - 2  = 2^{-2\zeta+9} $$
#
# Well this is annoying. There clearly is a solution but taking the log2 is inhibited by the term subtraction there. Mmmf. However, we do not have to do it algebraically, when we graph it we see the two sides intersect at exactly one palce, $\zeta=4$. Testing, we find that this makes:
#
# $$ \Rightarrow 2^{2} - 2  = 2 $$
#
# Which is true, so for mass equality over doubling, $\zeta = 4$. One may argue that we only showed this for the first doubling, but if we added another factor of 2 it would divide out, and the initial radius was general, so this proves the relation for all possible doublings. This also makes us thing that $\zeta=3$ is for surface area. Is it?
#
# $$ \left( (2R)^{-\zeta+3} - R^{-\zeta+3} \right) = \left( (4R)^{-\zeta+3} - (2R)^{-\zeta+3} \right) $$
# $$ \Rightarrow 2^{-\zeta+3} - 1  = 4^{-\zeta+3} - 2^{-\zeta+3}  $$
#
# And if we insert 3...
#
# $$ \Rightarrow 1- 1  = 1 - 1  $$
#
# Oh. Uh. Well yeah that is kind of obvious... wait. Wait hold on this is the *zero case,* excuse me...? This may not be a physically real answer! However, it is *also* at a discontinuity. *fascinating*. Let's see, what *does* happen when we approach those values for the total?
#
# These values actually *do* approach a limit, fascinatingly, it's not an infinite discontinuity. Calculating what that limit IS will be... nightmarish.
#
# As we found in the next part this discontinuity corresponds to the natural log solution. Which, doing a quick check, yes ln(8)-ln(4) = ln(4)-ln(2). So this IS the right answer, and it's physical. Neat!

# %% [markdown]
# *b) Prove that it is impossible to have both $R_{min} = 0$ and $R_{max} = \infty$ for any value of $\zeta$.*

# %% [markdown]
# This is actually easy. The number diverges in all cases. Remember, the number density is essentially proportioanl to:
#
# $$ x^{-\zeta} $$
#
# For negative values this just diverges as the x increases to infinity. For the 0 case, the integral still diverges as the radius goes to infinity as the constant value "1" just keeps adding more and more to it. Up to $\zeta=1$ we continue to have growth without bound.
#
# At $\zeta=1$ we have an odd discontinuity situation, but we can note that this is just 1/x, which goes to lnx, which diverges at r=0! for everything past this, we have things that go to 0 at large radii, BUT now we diverge at r=0!
#
# So basically no matter what happens things freak right out. That said it is interesting how ln(x) is like a SWITCH that just... turns it all off. Funky!

# %% [markdown]
# <a id='P11.11'></a>
#
# # Problem 11.11 \[Back to [top](#toc)\]
# $$\label{P11.11}$$

# %% [markdown]
# *Estimate (very crudely) the mass of Jupiter's ring system and associated inner moons. In parts a) - c) of this problem, you may assume that the ring particles have a density of 1 $g/cm^3$*
#
# *a) Estimate the mass of dust in each of the three parts of the ring system, assumign particle radii of 0.5 um in the halo and 1 um in the other regions. Use the optical depths given in 11.1.*

# %% [markdown]
# OKAY SO found the equation
#
# $$\tau = N\sigma$$
#
# $\sigma$ is the cross section of the paticles, while N is the *column density*, that is the number of particles *on* the path. Note that we know $\sigma$ and $\tau$ so we can FIND N.
#
# Our optical depths are not given very precisely but we can get some values anyway:
#
# Halo: 1e-6
#
# Main: 1e-6
#
# Amalthea: 1e-7
#
# Thebe: 1e-8
#
# Thebe Extension: 1e-9
#
# The cross section for the Halo is 7.854e-13 square meters. The other areas are given as 3.142e-12. Basically just pi, which, yeah, the radius is effectively 1. Anyway this gives us column densities of:
#
# Halo: 1.273e6
#
# Main: 3.183e5
#
# Amalthea: 3.183e4
#
# Thebe: 3.183e3
#
# Thebe Extension: 3.183e2
#
# And so number of particles times mass per particle times AREA. For the halo this is m=5.236e-16 kg and for everything else this is 4.189e-15. (volume times 1000 $kg/m^3$). We also need to find the area of the discs, and rings are *quite* extensive. Jupiter's raius is 6.991e7 m. Areas will be $\pi(R_2^2-R_1^2)$. In the following we give the areas and then the masses.
#
# Halo: 1.480e16; 9.866e6 kg. (Wow! That's diffuse!)
#
# Main: 4.656e15; 6.208e6 kg (Note that the main ring weighs less than the halo, this is due to the main ring being much smaller despite also being much denser).
#
# Amalthea: 5.009e16; 6.679e6 kg (Curiously each ring seems to *want* to stay at the same order of magnitude).
#
# Thebe: 9.781e16; 1.304e6 kg.
#
# Thebe Extension: 7.416e16; 9.888e4 kg. (This is the only one that weighs significantly less than all the others).
#
# In total we have about 24e6 kg. How much is that? Looking up a table of referneces, 1e6 kg is about a small bridge. So a medium bridge. This is the mass in a medium bridge. No wonder we can't see Jupiter's rings in most situations.

# %% [markdown]
# *b) Estimate the mass of the macroscopic particles in the main ring, assuming particle radii are:*
#
# *i) all 5 cm. ii) all 5 m. iii) Distributed as a power law with $N(R) \propto R^{-3}$ from 5 cm to 5 m. iv) Distributed as a power law with $N(R) \propto R^{-2}$ from 5 cm to 5 m. v) Distributed as a power law with $N(R) \propto R^{-3}$ from 5 cm to 500 m. vi) Distributed as a power law with $N(R) \propto R^{-2}$ from 5 cm to 500 m.*

# %% [markdown]
# So in order to do this calculation several times it's probably best to write down what we did in part a) in a more equation-based form.
#
# $$ N = \tau/\sigma = \tau / \pi r^2 $$
# $$ A = \pi(R_2^2 - R_1^2) $$
# $$ m = \frac43 \pi r^3 \rho $$
# $$ M = ANm = \frac{\pi(R_2^2-R_1^2) \tau \frac43 \pi r^3 \rho}{\pi r^2} = \pi(R_2^2-R_1^2) \tau \frac43 r \rho  $$
#
#
# Now, if we change the macroscopic particle size, that only adjusts r. Thus we can simply multiply everything else out to get:
#
# $$ M = 6.208e12 r $$
#
# So with particle sizes of um we would end up with 1e6 kg solutions. Yay! However, now we have new radii. There is some question as to whether we're doing what the problem wants, but eh, let's go through with it.
#
# If all particles are sized 5e-2 m, then we end up with
#
# M = 3.104e11 kg.
#
# And if we have the 5m result, we get
#
# M = 3.104e13 kg.
#
# Naturally not every particle is 5m, obviously, so this is a gross overestimate. Note that even this gross overestimate still pales in comparison to the 1e19 kg mass of Saturn's rings.
#
# However, at this point we reach something of an impasse. Because the distribution of particles is no longer uniform, so we have to integrate from the smallest particles to the largest to get the total mass. Keep in mind, we integrate over r, the *size*. Trying to set up a full integral became confusing, but we have an idea: what if we assign a weight to r? The final expression is in the form M=Ax, and A is constant, and x is our variable r. At any individual r this dependency should not change, even if we integrated both parts separately they still differ only by a factor of r at every point. Thus, a single value of *r* should be able to equal what the fully integrated value should be. With that, the idea is that we integrate from inner r to outer r along the distribution, and then divide to find the single value of r that works.
#
# Even this isn't exactly a simple integral, we need to find the r between $r_1$ and $r_2$ that splits the integral in half. The total integral is pretty simple; put the exponent as -E+1 so what follows is easy to write.
#
# $$ \frac{r_2^{-E} - r_1^{-E}}{-E} $$
#
# But we need to find precisely *half* of this. So, solve the following:
#
# $$ \frac{r_2^{-E} - r_1^{-E}}{-2E} = \frac{A^{-E}r_2^{-E} - r_1^{-E}}{-E} $$
# $$ \Rightarrow \frac{r_2^{-E} - r_1^{-E}}{2} = A^{-E}r_2^{-E} - r_1^{-E} $$
# $$ \Rightarrow r_2^{-E} - r_1^{-E} = 2A^{-E}r_2^{-E} - 2r_1^{-E} $$
# $$ \Rightarrow r_2^{-E} + r_1^{-E} - 2A^{-E}r_2^{-E} = 0 $$
# $$ \Rightarrow r_2^{-E}(1 - 2A^{-E}) + r_1^{-E} = 0$$
# $$ \Rightarrow r_2^{-E}(1 - 2A^{-E}) = - r_1^{-E} $$
# $$ \Rightarrow 1 - 2A^{-E} = - \frac{r_1^{-E}}{r_2^{-E}} $$
# $$ \Rightarrow 2A^{-E} = \frac{r_1^{-E}}{r_2^{-E}} + 1$$
# $$ \Rightarrow A^{-E} = \frac{r_1^{-E}}{2r_2^{-E}} + \frac12$$
# $$ \Rightarrow A = \left(\frac{r_1^{-E}}{2r_2^{-E}} + \frac12\right)^{-1/E}$$
#
# Which, is, well. A mess, yes, but we *can* calcualte it for any given exponential distribution.

# %% [markdown]
# For iii) This becomes $0.0141r_2 = 0.707 m$ for particle size, which translates to 4.389e11 kg.
#
# For iv) we have a smaller exponent which becomes $0.0198r_2 = 0.099m$ for particle size, which translates to 6.147e11 kg. Naturally both of these values are FAR below the "5 m" value since if every particle is 5 m that is quite absurd in terms of mass. Here most of the particles are small, the few larger ones just give a *bit* more mass to the whole situation.
#
# For v) the difference is a very large upper bound of 500m. Fortunately the calculation remains the same as the expression is arbitrary, so $0.0141r_2 = 7.05 m $, enough to push it past the 5m mass to 4.377e13 kg.
#
# For vi) it's even larger, 9.9 m effective radius, 6.146e13 kg.

# %% [markdown]
# *c) Estimate the mass of the moon Metis, using the size given in Table 1.5.*

# %% [markdown]
# If we assume Metis is mostly icy, we get for the 30x20x17km awkward object a mass of 1.02e16 kg. This moon is small enough to be decidedly unspherical so this is reasonable. Still pathetic compared to the 1e19 mass of saturn's rings.

# %% [markdown]
# *d) Compare the uncertainties introduced by the assumed density to those resulting from uncertainties in the particle size distribution.*

# %% [markdown]
# So, this depends on how you want to quantify the size distribution argumetns.
#
# If we just consider part a), making the rings made entirely of microscopic dust as a guess, then we range over as many orders of magnitude as we think the particle sizes take. However, we think it's more reasonable to examine b) as the actual mass, since there are probably larger particles that hold most of the mass. In fact, let's test that out! If we extend the distribution for $r_1$ all the way down to micrometer values, how does that change the overall mass? Actually that changes it quite a bit, the mass goes down significantly to the order of 1e7 kg if we extend it back all the way to dust for the 5m largest object case. So yeah uh the distribution has *seeeeveral* order of magnitude fluctuations.
#
# Meanwhile the assumed density of the particles? Water is pretty much the lighest thing they can be barring porosity, so 1 is a lower bound, and the density of the earth is about 5, so there aren't actually that many values it *could* be. And if we look in part a) the density is just a direct multiplicative factor, so the *most* it does to the answer is a *single* order of magnitude adjustment. Meanwhile we're over here jumping from 1e7 to 1e13 kg with the particle size distributions. So, uh, yeah the size distribution change is pretty clearly not constrained at all compared to the density and influences the answer a lot more.

# %% [markdown]
# <a id='P11.12'></a>
#
# # Problem 11.12 \[Back to [top](#toc)\]
# $$\label{P11.12}$$

# %% [markdown]
# *The moonlet Pan orbits within the Encke gap in Saturn's rings.*
#
# *a) Calculate the location of Pan's 2:1 inner Lindblad resonance using the Keplerian approximation for orbits.*

# %% [markdown]
# We're going to assumet this means the simple resonance that we would calculate between two moons. So, if it's an inner resonance, the "2" applies to the inner orbit. Kepler's third law says $T^2 \propto a^3$, so if we replace T with T/2 we get an a of:
#
# $$ \frac{a}{2^{2/3}} $$
#
# Or 0.630a. Pan orbits at 133e3 km, so this is 83.8e3 km. Using The Saturnian radius of 58e3km, this is 1.44R. Which is smack dab in the middle of the C ring. On a diagram of Saturn's rings this area doesn't appear to be that notable but there's always ring features everywhere.

# %% [markdown]
# Of course we WERE asked specifically for the Lindblad resonance. The *approximation* (which is not labeled as the Keplerian approximation by the way) is that
#
# $$ \frac{n(r_{L,v})}{n_s} \approx \frac{m_\theta + m_z + m_r}{m_\theta - 1} $$
#
# We are looking for the 2:1 resonance, we just need to get ahold of n as a function of r. n is just the angular velocity of the system, and $n^2 = GM/r^3$ which means $n^2 \propto r^{-3}$. Note, however, that for a 2:1 resonance we want double n, while we wnated half T. Thus the method above is identical to this one, the same result for a will be obtained.

# %% [markdown]
# *b) Calculate the location of Pan's 2:1 inner Lindblad resonance more precisely.*

# %% [markdown]
# Now we try to do this with more care using the actual Lindblad Resonance equation:
#
# $$ \omega_f - m_\theta n(r_L) = \pm \kappa (r_L) $$
# $$ \omega_f = m_\theta n_s + m_z \mu_s + m_r \kappa_s $$
#
# From the approximation we do know the values of some of these values though: $m_\theta$ must be 2 to hold the denominator at 1, andt hus $m_z + m_r = 0$. Unfortunately since we're not using the approximation we can't just have these things cancel, and while they are integers they can take negative values so that doesn't restrict them either. They must both be zero or equal and opposite. Since we are looking for Lindblad Resonance, we know we are looking for horizontal resonance, which restricts $m_z$ being even. With all this we have:
#
# $$ \omega_f - 2n(r_L) = - \kappa (r_L) $$
# $$ \omega_f = 2n_s + 2j\mu_s -2j\kappa_s $$
#
# j is used to represent "an integer." We set the sign to lower as we only care about the inner resonance.

# %% [markdown]
# Now we know what n is, the angular velocity. But what about the other variables? $\mu$ is vertical oscillation frequency, $\kappa$ is the radial frequency. And so how do we calculate these things? Well, we find out by looking at page 39 and finding... ...that this insolves the $J_2$ deviation from spherical symmetry from Saturn. Uuuugh fine, only doing it to first order though, $J_2 = 1.63e-2$ for Saturn. And...
#
# $$ n^2 = \frac{GM}{r^3}\left(1 + \frac32 J_2 \frac{R^2}{r^2}\right) $$
# $$ \kappa^2 = \frac{GM}{r^3}\left(1 - \frac32 J_2 \frac{R^2}{r^2}\right) $$
# $$ \mu^2 = 2n^2 - \kappa^2 $$
#
# This... this will jsut be such a tedous calculation. However, we can't justify skipping it, because of one detail: we don't know what j is. However, digging into the book we find the *strongest* resonance is at $j=0$. Presumatly this is the one they want. If so, then...
#
# $$ 2n_s - 2n(r_L) = - \kappa (r_L) $$
# $$ \Rightarrow 2n_s = 2\sqrt{\frac{GM}{r^3}\left(1 + \frac32 J_2 \frac{R^2}{r^2}\right)} - \sqrt{\frac{GM}{r^3}\left(1 - \frac32 J_2 \frac{R^2}{r^2}\right)} $$
# $$ \Rightarrow 2\sqrt{\frac{GM}{r_1^3}\left(1 + \frac32 J_2 \frac{R^2}{r_1^2}\right)} = 2\sqrt{\frac{GM}{r^3}\left(1 + \frac32 J_2 \frac{R^2}{r^2}\right)} - \sqrt{\frac{GM}{r^3}\left(1 - \frac32 J_2 \frac{R^2}{r^2}\right)} $$
#
# Which we can simplify... not much.
#
# $$ \Rightarrow 2\sqrt{\frac{1}{r_1^3}\left(1 + \frac32 J_2 \frac{R^2}{r_1^2}\right)} = 2\sqrt{\frac{1}{r^3}\left(1 + \frac32 J_2 \frac{R^2}{r^2}\right)} - \sqrt{\frac{1}{r^3}\left(1 - \frac32 J_2 \frac{R^2}{r^2}\right)} $$

# %% [markdown]
# Anyway at this poitn we see that there *will* be a solution, and that if $J_2 = 0$ we would get our old solution back. We choose *not* to go through all this tedium. Ugh deviations from spherical gravity fields are pain... (An exact solution would require computational methods anyway, we would most likely resort to a taylor approximation for the square root.)

# %% [markdown]
# *c) Is this resonacne within Saturn's rings? If yes, state which ring.*

# %% [markdown]
# As the second-order approximation will not change much, it'll still be within the C ring.

# %% [markdown]
# *d) What type of wave is such a resonance capable of exciting? How many spiral arms would it have?*

# %% [markdown]
# Lindblad resonances are horizontal resonances, and thus would produce spiral density waves, akin to the spiral arms in a galaxy. As this is a density wave the disc itself doesn't ripple. And a 2:1 resonacne would have two arms. (we can kind of think of this like tides actually, both the furthest and closest points get "kicks" in opposite directions relative to the center.)

# %% [markdown]
# <a id='P11.14'></a>
#
# # Problem 11.14 \[Back to [top](#toc)\]
# $$\label{P11.14}$$
#
# *b) Calculate the location of the expected crests of the density wave excited by this resonance (Enceladus 3:1 inner Lindblad) if the surface density of the ring is $50g/cm^2$. You may assume that a crest occurs at exact resonance. Is this a reasonable assumption? Comment.*

# %% [markdown]
# So, the crests occur at exact resonance. As it is an inner resonance, the crests will propogate inward. The obvious question is how *fast* will they propogate inward? Aka, how much winding is there?
#
# Well to answer that we need at least a basic approximation to the radius, which we can do using the same thing we did in 11.12a, using Kepler's Third Law.
#
# $$ \frac{a}{3^{2/3}} $$
#
# Enceladus orbits at 238e3 km, so its 3:1 resonance here is at 114e3 km, which is the outer edge of the B ring near the Cassini Division. One might wonder if corrections would place it IN the Cassini Division, but no that's Mimas' resonance in the Cassini Division.
#
# Anyway we have a number. We can now find the wavelength.
#
# $$ \lambda(r) = 3.08 \left( \frac{r_L}{R} \right)^4 \frac{\sigma}{m_\theta - 1} \frac{1}{r_L-r} $$
#
# So to avoid some complications, let's assume $\sigma$ is constant throughout the rings (it isn't). We choose a middle value of 200 $kg/m^2$ or 2000 $g/cm^2$. WE set $m_\theta$ to 2 so it can match the 3:1 resonance and dooon't worry about the other parts. The other parts are saturn radius and the resonacne radius, which we have. So...

# %% [markdown]
# $$ \lambda(r) = 3.08 (14.925) (2000) \frac{1}{144e3 -r} = \frac{91900}{144000 - r}$$

# %% [markdown]
# This plots something like this:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# x is negative since the waves are propogating inward. Wavelength starts out large and then gets smaller and smaller with distance, but the rate at which it gets smaller tapers off. This matches what we see in the book. The wavelength in kilometers (despite the density being in cenimeters, it's what the book says to do don't ask). This these waves oscillate a few times each kilometer as we go further down, which matches the extremely tight winds we see in the Saturnian system.
#
# Now, does a crest occur at exact resonance? Well, not everywehre at the exact resonance, in three places even in our model. But is our model accurate?
#
# We, uh, hmm. Aren't sure... I can think of reasons for "yes there's always a crest" and "well no not always". Hmmm.

# %% [markdown]
# A thought: think about it like tides. if there is no viscocity or retarding forces, the water would always be directly in line with the moon. It is not, though, due to a delay. The viscocity of Saturn's rings isn't zero, though it's very low, and response times are not *immediate* in any case. So while we think it's a good assumption that a crest occurs at exact resonance, strictly speaking there will have to be deviations.
#
# Addendum: resonances always take shapes of the larger number = spiral arms, the lower number does not change shape. In a 3:1 or 3:2 resonance, there are still three crossings in a full "cycle."

# %% [markdown]
# <a id='P11.20'></a>
#
# # Problem 11.20 \[Back to [top](#toc)\]
# $$\label{P11.20}$$

# %% [markdown]
# *The probability that a photon traveling towards a planetary ring will interact with a ring particle depends upon the angle between the photon's path and the ring plane (Problem 11.6). but it does not depend (significantly) upon whether the in plane component of the photon's velocity is in the direction of particle orbits or opposite to them because photons move much more rapidly than do ring particles. However, the velocity of interplanetary debris is only slightly larger than that of ring particles, so particle motion during the passage of this debris through the ring disk cannot be neglected in determining collision probabilities. By decomposing the velocity of the debris into cylindrical polar coordinates in the planetocentric system, derive a fomrula for the impact probability as a function of speed (relative to the orbital velocity of the ring particles), direction, and ring normal optical depth, $\tau$.*

# %% [markdown]
# So the probability for ring particle interacitons we found in 11.6 was...
#
# $$e^{-4\tau D/d}$$
#
# Where $\tau$ is the optical depth for a photon, d is the normal distance, and D is the distance actually traveled.
#
# $$ D^2 = d^2 + d^2 tan\theta $$
#
# We can go a step further and point out that the d-dependence cancels out.
#
# $$e^{-4\tau \sqrt{1+tan\theta}}$$
#
# Note that this IS an approximation, dead-on angles treat the rings as an infinite slab and will diverge, while real rings do have an upper limit.

# %% [markdown]
# Anyway, this is when the relative ring speed is 0 in the translational direction (the ring's movement direction, or the angular direction). But what about when we come in at a differing speed? Call this v. v=0 at our previous spot, and v can take either positive or negative values depending on if it is faster or slower respectively.
#
# We have now realized another issue: the speed at which we pass through the rings in the vertical direction also matters--after all, since it's so big for light the translational motion of the particles is small. BUUUT now that the prticles move the time scale over which we cross the rings is much more important.
#
# So, new plan, v is now the vectoral velocity. Thus our components are:
#
# $$ \vec v = - v cos\theta \hat y + v sin\theta \hat x$$
#
# The y direction velocity is only relevant in that it tells us how long we have for the particles to move. In this case it is
#
# $$1/t = \frac v d cos\theta $$
#
# Except this is NOT the number we need, as a particle flying through the rings doesn't see a cross section equivalent to the particle smeared across over the entire time, merely the particle smeared across *while the diameter of the particle itself is being crossed*. So in actuality we should replace d with 2R to get the time where it's *possible* the moving particle can move into the line of sight.
#
# $$ 1/t = \frac{v}{2R} cos\theta $$
#
# We basically seek how much effective cross sectional area a moving particle with that much time creates. This is going to be the following shape:
#
# ![image-2.png](attachment:image-2.png)
#
# The distribution we see here is for a ring particle moving much faster than the incoming particle, which gives us an integrable shape. However, when it's *comparable*, we have an *overlap problem*.
#
# ![image-3.png](attachment:image-3.png)
#
# This fat slug does *not* start as points at either end, but rather has significant bleed over. We are decidedly unsure how to find the area of this shape. That said it is *very* clear that the faster relative speed covers a larger area. ALso note that there should be no difference between positive and negative relative speed: the same area is covered if relative prograde or retrograde, when we treat the ring particles thesmevles as the stationary refernece. (As they are not naturally an outside observer will notice a difference).
#
# After quite a bit of analysis, we decided there *was* a way to do it. We declare there to be three parameters in a function: x, X, and T. x and X are physical locations, while T is half of the distance covered by the particle. (it starts at -T and goes to T to keep symmetry).
#
# Now, why x and X? Well, this is because we had a function for the shape of the particle's cross section at any given time: it's a circle. At every point along the line from -T to T, a circular cross sectional area is seen. Its center is determined by X. Because of this, we can imagine a circle with center X that nonetheless extends beyond the boundary of T due to its radius. Thus, X determines the center, while x gives us the coordinate of the circle itself. We will essentially examine all possible X states at once and find the one with the largest x -- that is the furthest extent of the cross section as seen from a path cutting through it. (Note: this would be different for very large angles of incidence, which we are already ignoring due to the slab approximation).
#
# The first step in constructing this function is to create the bounds on what X can be and what part of the spherical particle we are looking at. This is
#
# $$ \sqrt{1 - \frac{X^2}{T^2}} $$
#
# The behavior of this function is as follows:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# T decides the "length", here we have T=3.8. T will be calculated from v and R later. Anyway, equipped with this, we now need to find the size of the semicircle at every center X. This equation means the "radius" is the value of the above function for every X. Thus...
#
# $$ \sqrt{ 1 - \frac{X^2}{T^2} - (x-X)^2} $$
#
# Which when we select an X will give us a semicircle of the appropriate size.
#
# ![image.png](attachment:image.png)
#
# Note that the edges extend beyond the edge. It's supposed to do this, we deisnged it explicitly to do this.
#
# Anyway, so here's whaat we do now. We want a function of x that will automatically choose the largest value across all X. Thus, we need to arbitrarily maximize X. We can do this! If we square the above function and take the derivative with respect to X, we get:
#
# $$ -2X (\frac{1}{T^2} + 1) + 2x $$
#
# To maximize we find the place the derivative is zero, and there is only one. We don't need to check if there is a maximum since we know there has to be one, and anything outside the radical's normal range would be negative anyway.
#
# $$ X = \frac{x}{\frac{1}{T^2} + 1}$$
#
# Which means that the function that describes the SHAPE of the cross sectional area of a moving particle is:
#
# $$ \sqrt{ 1 +\frac{x^2}{\frac{1}{T^2} + 1} - x^2} $$
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# And this behaves as it is supposed to. We can't show it here but if we allow X to varry on the circle function, we see that our area function is always a nice tangent line on the created circles. Anyway, to get the ACTUAL area, we'll need to take an integral. (And double it since under the number line counts as well.)
#
# $$ 2\int_{-T}^{T} \sqrt{ 1 +\frac{x^2}{\frac{1}{T^2} + 1} - x^2} dx $$
#
# This is actually a known integral $\sqrt{1 + ax^2}$. Is the result neat? Not really.
#
# $$ 2\left[ \frac{asinh(\sqrt{a}x)}{2\sqrt{a}} + \frac{x\sqrt{1+ax^2}}{2} \right]_{-T}^{T} $$
#
# And neither of these terms can make much use of equal symmetric bounds either, nothing cancels, everything is odd though so there is that.
#
# $$ 2\frac{asinh(\sqrt{a}T)}{\sqrt{a}} + 2T\sqrt{1+aT^2} $$
#
# Where T = vt and $a = \frac{1}{\frac{1}{T^2} + 1}$. Let's just call this *entire thing* the cross sectional area $\sigma$.
#
# So to find the probability we need to be *slightly* careful. We found the cross sectional area for R=1, you may note this because the maximum height *was* 1. Naturally as this is an area it still has to scale with $R^2$, which in the case of our particles is $4R^2$. So what we have is $4R^2\sigma$. This means that what we found for $\sigma$ is the multiplication factor for the probability.
#
# Thus the probability is
#
# $$e^{-\sigma\tau \sqrt{1+tan\theta}}$$
#
# Is there a way to simplify this? Most definitely, we can probaly work out $R^2$ entirely if we try hard enough.

# %% [markdown]
# Trying to check what happens when we set v to absurd sizes gets us not really anywhere, probably because assumptions start breaking down. That said, our *graphical* interface shows that our integrated function turns into a circle at T=0, so that's a good sign.

# %% [markdown]
# <a id='P12.7'></a>
#
# # Problem 12.7 \[Back to [top](#toc)\]
# $$\label{P12.7}$$

# %% [markdown]
# *Calculate the probability of transits of the planets Venus and Jupiter being observable another (randomly positioned) planetary system.*

# %% [markdown]
# So rather than doing this for specific planets, lets consider this in generality (for circular orbits).
#
# First, let's say they had *perfect* telescopes that could detect light variations no matter how much, so size isn't an issue, and proximity to the star isn't either. We just care that it's *possible* to observe. Time is also irrelevant: a planet can take 10,000 years to go around but if it transits during that time, it's considered observable.
#
# So, basically, we need to determine the fraction of the sky a planet casts a shadow on. The very simplest ways to do this is to treat a star as a point source and see if the planet covers it. This'll serve as a rather good first order approximation. (Naturally this doesn't count grazes, only things that transit over the center).
#
# Anyway the surface area of a celestial sphere at any distance is $4\pi r^2$, with r being the solar distance. The planet is essentially a flat circle shadow of area $\pi R^2$ with R being the planetary radius. HOWEVER, this is just the area at any given moment, since we want the area of the sky that can have *any* transit, So what we actually have is a ring with height 2R and circumference $2r\pi$, and thus the actual area is $4\pi R r$. If we divide this as a fraction we then get that this shadow ring takes up $R/r$ of the sky. Since r is almost always stupendously larger than R, this is pretty sensible.
#
# For Jupiter we have 1.837e-6 of the sky and Venus 1.119e-4.
#
# Keep in mind that this is just for eclipses which cross the center, the actual area will be *larger* than this. Let's assume it'll give us an order of magnitude, in which case 1 in 1e5 star systems we observe with a Venus-like planet will have a visible transit, and 1 in 1000 for Jupiter-like planets. (that is planets of Jupiter's radius at juptiter's distance from the star).

# %% [markdown]
# <a id='P12.8'></a>
#
# # Problem 12.8 \[Back to [top](#toc)\]
# $$\label{P12.8}$$

# %% [markdown]
# *a) Calculate the ratio of the light reflected by the Earth at 0.5um to that emitted by the Sun at the same wavelength.*

# %% [markdown]
# The sun is a blackbody(ish) so its emission at any wavelength can just be calculated.
#
# $$ B_\nu(T) = \frac{2h\nu^3}{c^2} \frac{1}{e^{h\nu/kT} - 1} $$
#
# Now in this case, we are dealing with a *reflection* problem and the answer is a ratio, so we don't need to calculate it out fully. (Though part b) is going to care about this).
#
# Let the sun release some amount of energy B. Only a tiny fraction of it reaches Earth, specifically the fraction of a circle on the entire celestial sphere, which is $\frac{R^2}{4r^2}$, with r as the distance to Earth and R as Earth's radius. This is 1.818e-9. Now this is just the energy that REACHES Earth, what's its albedo at 0.5um?
#
# Bizarre, there appears to be nothing about albedo in this chapter, making us think we're maybe going about this unusually. Regardless, we can look up, Earth abledos. It seemed difficult at first as nobody has thought to make a plot of wavelenth-dependent albedos, but we realized what we're given is 500nm, aka green-blue light, so the standard albedo should work. 0.3. 5.45e-10. It's basiclaly tiny.

# %% [markdown]
# *b) Calculate the ratio of the thermal radiation emitted by Earth at 20um to that emitted by the Sun at the same wavelength.*

# %% [markdown]
# In this case we can divide two Planck funcitons by each other, just at different T values.
#
# $$ \frac{e^{h\nu/kT_S} - 1}{e^{h\nu/kT_E} - 1} $$
#
# There doesn't really appear to be a way to simplify this so just start calculating. Earth temp is 288 K, Solar temp is 5772. Wavelength is 20e-6, k is 1.380e-23, and h is 6.626e-34. The result is...
#
# $$ \frac{e^{8.319e-15} - 1}{e^{1.667e-13} - 1} $$
#
# Which is to say we can say that the Earth certainly produces *less* than the sun but that it's not by much!
#
# Anyway sice the exponent is so small the value can be determined by Taylor Expansion to first order, aka 1+x. Thus the fraction reduces to
#
# $$ = \frac{8.319e-15}{1.667e-13} = 0.0499$$
#
# This is Earth over Sun, so the sun is about 20 times more luminous in this region. Kind of expected, while higher temp bodies *always* have more at every wavelength, outside their peaks the increase is often minimal.

# %% [markdown]
# *c) Repeat the above calculations for Jupiter.*

# %% [markdown]
# Didn't bother, already learned what we needed to from the previous parts we think. Mindly concerned that the question was asking for something different than what we did though.

# %% [markdown]
# <a id='P12.14'></a>
#
# # Problem 12.14 \[Back to [top](#toc)\]
# $$\label{P12.14}$$

# %% [markdown]
# *Radii and masses measured for five hypothetical transiting planets are listed below. State the ranges in composition consistent with these measurements. In some cases, the ranges allowed by the error bars include some unlikely or unphysical compositions. Which cases are these, and why?*
#
# *a) $R = 3\pm 1$ Earth, $M = 3\pm 1$ Earth*

# %% [markdown]
# So, let's get oursevels a baseline here. Earth itself will have a radius of 1 and a mass of 1 in this way of measuring, which means the *density* is $\frac{3}{4\pi}$. However when we report density values they will be given as "part" of this value.
#
# Anyway from here on out we will take the "four corners approach" -- finding the density from all extremes.
#
# In every case the densities are lower than Earth, considerably so, 0.5, 0.25, 0.0625, 0.03125. The actual density of Earth is 5$g/cm^3$. so our highest density is 2.5$g/cm^3$, reasonable for a mixed ice/rock body, but the lowest is 0.156$g/cm^3$! That's ridiculous! The Density of SATURN is 0.68, and that's higher than this! A body this small can't be composed primarily of hydrogen and helium, it would escape to space.
#
# Now we note that our variations range from half-density to very low density, so presumably this is a rather low density object. As it would be unusual for a rocky world the size of Earth to have significantly *lower* density, we have two potential concusions: this is an icy world or there is an extensive thick atmosphere. The densities on the high end match what we would expect from icy worlds, Enceladus sitting at 1.6$g/cm^3$, and naturally a larger mostly-icy would would gain greater density due to pressurization. However, *most* of the range of values lies in even less dense areas, which means we can think of a very icy world with an extensive atmosphere, which could be caused by heating. The more we think about this the more we think this is an ocean world with an extensive water vapor atmosphere, which can explain the large size but low density.

# %% [markdown]
# *b) $R = 1\pm 0.5$ Earth, $M = 3\pm 1$ Earth*

# %% [markdown]
# So, our densities this time are (related to Earth) 32, 16, 1.19, 0.59. Which is to say some *really* big densities that go down to a little below Earth's density itself. We will note that the density of pure iron is 7.8$g/cm^3$! Not even 2 times Earth's density! Even a highly metallic and compressed world would not get to the high end of these ranges! Meanwhile the low end are just standard rocky Earthlike worlds without much fanfare. In fact most of the considerations here are absolutely absurd, nothing should be denser than, say, 2 earths. The *densest* planet ever discovered was 11$g/cm^3$m, a little over 2, so yeah those are quite absurd.
#
# Since most of our measurements lie in this region, though, we are forced to conclude that we *are* looking at a very dense metal rich planet, perhaps an exposed gas giant core or partially exposed metallic core. Freaky. Just goes to show though that our density values also cross normal Earth values, and that most of our values here are absolutely bonkers. The mass of two earths condensed into a size smaller than it? Ridiculous.
#
# So yeah for this one we submit "metal rich world."

# %% [markdown]
# *c) $R = 12\pm 2$ Earth, $M = 300\pm 100$ Earth*

# %% [markdown]
# The densities we have here are 0.4, 0.2, 0.146, 0.0729 earth densities. AGain, low values, BUT we are in a larger size range, specifically the size range of Ice Giants. Here we expect values about 1.6$g/cm^3$ which is about 0.32. The lowest density is a *tad* ridiculous, 0.36$g/cm^3$, less dense than Saturn, but it's an extreme and it's not that far from the normal values--0.4 and 0.2 are both normal, and even 0.146's value isn't too riduclous, with a between Jupiter and Saturn density, which could be accomplished by superheating and atmosphere expansion. So everything here is possible, but most likely it's probalby just a Neptune analogue.

# %% [markdown]
# *d) $R = 3\pm 1$ Earth, $M = 30\pm 10$ Earth*

# %% [markdown]
# The densities are 5, 2.5, .625, .3125. The large end is once again too large to be reaonsable, but not as badly as part b). The low ends are suitable for icy or icy-rocky mixtures. This object could be any number of things ranging from the massive metal core to a mostly icy world to a heavy world with a dense atmosphere. All things are on offer here, and as it's a super-earth we know basiclaly nothing about them to begin with so. Uh. Shrug.

# %% [markdown]
# *e) $R = 2\pm 0.2$ Earth, $M = 10\pm 1$ Earth*

# %% [markdown]
# Finally a precise radius value, these imprecise radii values have been what send our error bars all over the place. The relation we use looks like $M/R^3$ for density, note the CUBIC relation on radius. We can afford more uncertainty in mass than we can in radius.
#
# Anyway for this we have 1.88, 1.54, 1.03, 0.845.
#
# Which is to say we can be fairly certain this is a rocky world with similar composition to Earth. The range of values kind of cneter around it and both the largest and smallest values are not unreasonable. IF we chose the exact middle this would have slightly more density than Earth, which is to be expected for a superearth as it can compress things more.
