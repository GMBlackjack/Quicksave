# %% [markdown]
# # Homework 9: I've Been Working on the Railroad...
# ## Quantum Mechanics II: PHYS 511
# ## Gabriel M Steward
# ## March 2022
# **Texts Referenced:**
#
# **Modern Quantum Mechanics, Sakurai and Napolitano**
#
# **Introduction to Quantum Mechanics, Griffiths and Schroeter**
#
# **(Further references at the end)**

# %% [markdown]
# ## Problem 1
#
# ![Screenshot%202022-03-27%20111016.png](attachment:Screenshot%202022-03-27%20111016.png)

# %% [markdown]
# ## Problem 2
#
# ![Screenshot%202022-03-27%20111224.png](attachment:Screenshot%202022-03-27%20111224.png)

# %% [markdown]
# ## Additional References

# %% [markdown]
# Geogebra for plotting and integration.
