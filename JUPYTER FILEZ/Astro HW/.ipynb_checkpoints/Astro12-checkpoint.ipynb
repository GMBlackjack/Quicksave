# %% [markdown]
# # Homework 11: R E S O N A T E
#
# ## Astrophysics: PHYS 584
#
# ## Gabriel M Steward
#
# ## April 2022
#
# **Texts Referenced:**
#
# **An Introduction to Modern Astrophysics, Carroll and Ostlie**
#
# **Lecture Notes.**
#
# **Kerbal Space Program.**

# %% [markdown]
# ## Problem 1
#
# **The Laplace Resonance: Io, Europa, and Ganymede**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 2
#
# **Resonance Periapse Precession Rates**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 3
#
# **Hill Spheres**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
