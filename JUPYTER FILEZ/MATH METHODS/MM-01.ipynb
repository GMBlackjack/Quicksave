# %% [markdown]
# # Math Methods Homework 1: Deja Vu
#
# ## Gabriel M Steward
#
# ### September 2022

# %% [markdown]
# <a id='toc'></a>
#
# # Table of Contents
# $$\label{toc}$$
#
# [Problem 1](#P1) (Our Good Friend the Gram-Schmidt Procedure)
#
# [Problem 2](#P2) (Nonlinear Operator)
#
# [Problem 3](#P3) (Exponentially Rotating)
#
# [Problem 4](#P4) (Inverse Invertable Uniqueness)
#
# [Problem 5](#P5) (Commutator)

# %% [markdown]
# <a id='P1'></a>
#
# # Problem 1 \[Back to [top](#toc)\]
# $$\label{P1}$$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <a id='P2'></a>
#
# # Problem 2 \[Back to [top](#toc)\]
# $$\label{P2}$$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <a id='P3'></a>
#
# # Problem 3 \[Back to [top](#toc)\]
# $$\label{P3}$$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <a id='P4'></a>
#
# # Problem 4 \[Back to [top](#toc)\]
# $$\label{P4}$$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <a id='P5'></a>
#
# # Problem 5 \[Back to [top](#toc)\]
# $$\label{P5}$$
#
# ![image.png](attachment:image.png)
