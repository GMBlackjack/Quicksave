# %% [markdown]
# # Numerical Relativity Problems Chapter 11: Recasting the Evolution Equations
#
# ## Authors: Gabriel M Steward

# %% [markdown]
# https://github.com/zachetienne/nrpytutorial/blob/master/Tutorial-Template_Style_Guide.ipynb
#
# Link to the Style Guide. Not internal in case something breaks.

# %% [markdown]
# ### </list_source_code> NRPy+ Source Code for this module:
# None, save the pdf conversion at the bottom of this document.
#
# ## Introduction:
# Before we end this summer, we will (we must!) get to the end of BSSN, which is contained in this chapter.
#
# ## </other>  Other (Optional):
# In order to fascilitate learning, whenever the opportunity arises Sympy will be used. (Which turns out not to be that often all things considered...)
#
# ### Note on Notation:
# Any new notation will be brought up in the notebook when it becomes relevant.
#
# ### Citations:
#
# <a id='1'></a>
# [1] linky (descrip)

# %% [markdown]
# <a id='toc'></a>
#
# # Table of Contents
# $$\label{toc}$$
#
# [Problem 1](#P1) (Coulomb Gauge)
#
# [Problem 2](#P2) (Derivation of BSSN, incomplete)
#
# [Problem 3](#P3) (The Secret Equation, skipped)
#
# [Problem 4](#P4) (Wave Equation Satisfaction)
#
# [PDF](#latex_pdf_output) (turn this into a PDF)

# %% [markdown]
# <a id='P1'></a>
#
# # Problem 1 \[Back to [top](#toc)\]
# $$\label{P1}$$
#
# *Show that in the Coulomb gauge the gauge potential $\Phi$ satisfies Poisson's elliptic equation $D^iD_i\Phi = -4\pi \rho_e$.*

# %% [markdown]
# The Coulomb Gauge says $\Gamma = D^i A_i = 0$
#
# 11.4 gives us a very helpful relation:
#
# $$ \partial_t A_i = -E_i -D_i\Phi $$
#
# Contract with $D^i$
#
# $$ D^i \partial_t A_i = -D^i E_i - D^i D_i\Phi $$
#
# $D^i E_i$ is the constraint 11.6.
#
# $$ D^i \partial_t A_i = -4\pi\rho_e - D^i D_i\Phi $$
#
# And we re-arrange...
#
# $$ D^i \partial_t A_i + D^i D_i\Phi = -4\pi\rho_e$$
#
# Which is really close. Now, if $D^i \partial_t$ commutes, we end up with $D^i A_i$ which goes to zero in our gauge. However, WE DO NOT KNOW IF THEY COMMUTE. We do know that we are dealing with Maxwell's equations so $D^i = \nabla^i$ and $\partial_t = \nabla_t$.
#
# $$ \nabla^i \nabla_t A_i + D^i D_i\Phi = -4\pi\rho_e$$
#
# But covariant derivatives need not commute, either. If we were SUMMING over BOTH indices, it would be fine, but we are not. ($\nabla_t$ isn't really an index anyway.)

# %% [markdown]
# So let's try to show that the term CAN commute. Test the equality.
#
# $$ \nabla^i \partial_t A_i = \partial_t \nabla^i A_i $$
#
# Split up the covariant derivative, knowing that in EM it is equal to the spatial covariant derivative, we don't have to worry about the 4-index that shows up.
#
# $$ \partial^i \partial_t A_i + \Gamma^{ki}_i \partial_t A_k = \partial_t \partial^i A_i + \partial_t (\Gamma^{ki}_i A_k)$$
#
# The first terms match since partial derivatives DO commute, good. Product rule the last term.
#
# $$  \Gamma^{ki}_i \partial_t A_k = \Gamma^{ki}_i \partial_t A_k + A_k \partial_t \Gamma^{ki}_i $$
#
# Now, remember, we are in Maxwell's equations. Here, the metric cannot be changing in time, which means the Christoffels must also be constant, thus the last term goes to zero.
#
# $$  \Gamma^{ki}_i \partial_t A_k = \Gamma^{ki}_i \partial_t A_k $$
#
# Which means that, yes, in the EM situation our operators DO commute. Which means we can say...
#
# $$ \partial_t D^i A_i + D^i D_i\Phi = -4\pi\rho_e \Rightarrow D^i D_i\Phi = -4\pi\rho_e $$
#
# Bonus thought: perhaps modeling $\partial_t$ as $t^a \partial_a$ would have helped?

# %% [markdown]
# <a id='P2'></a>
#
# # Problem 2 \[Back to [top](#toc)\]
# $$\label{P2}$$
#
# *Derive equations 11.35 through 11.38*
#
# Ah, so we're actually going to derive BSSN! Gooooood...

# %% [markdown]
# ROUND 1: 11.35, evolution of $\phi$
#
# $$\partial_t \phi = -\frac16 \alpha K + \beta^i \partial_i \phi + \frac16 \partial_i \beta^i$$

# %% [markdown]
# 2.136 is our friend the (annoying) $\partial_t ln\sqrt{\gamma} = -\alpha K + D_i \beta^i$. The variable we are seeking to relate this to is $\phi = \frac{1}{12} ln(\gamma/\eta)$

# %% [markdown]
# $$
# \begin{align}
# \partial_t \frac12 ln\gamma &= -\alpha K + D_i \beta^i \\
# \Rightarrow \partial_t ln\gamma &= -2\alpha K + 2D_i \beta^i \\
# \Rightarrow \partial_t 12\phi + \partial_t ln\eta &= -2\alpha K + 2D_i \beta^i \\
# \Rightarrow \partial_t \phi &= -\frac16 \alpha K + \frac16 D_i \beta^i \\
# \Rightarrow \partial_t \phi &= -\frac16 \alpha K + \frac16 \partial_i \beta^i + \frac16 \beta^a \Gamma^i_{ai} \\
# \Rightarrow \partial_t \phi &= -\frac16 \alpha K + \frac16 \partial_i \beta^i + \frac16 \beta^k \Gamma^i_{ki} \\
# \end{align}
# $$

# %% [markdown]
# Now, this is close, but that last term is somewhat problematic. However, if we were to evaluate what that Christoffel equals...
#
# $$
# \begin{align}
# \Gamma^i_{ki} &= \frac12 \gamma^{il}(\partial_k \gamma_{il} + \partial_i \gamma_{kl} - \partial_l \gamma_{ki}) \\
# \Rightarrow \Gamma^i_{ki} &= \frac12 \gamma^{ii} (\partial_k \gamma_{ii} + \partial_i \gamma_{ki} - \partial_i \gamma_{ki}) \\
# \Rightarrow \Gamma^i_{ki} &= \frac12 \gamma^{ii} \partial_k \gamma_{ii}\\
# \Rightarrow \Gamma^i_{ki} &= \frac12 \partial_k ln \gamma\\
# \end{align}
# $$
#
# The last step here is MNR-2.125. We still aren't sure why it's true but it's a given relation so we'll take it. Performing this substitution (and replacing k with i for consistency) we get
#
# $$
# \begin{align}
# \Rightarrow \partial_t \phi &= -\frac16 \alpha K + \frac16 \partial_i \beta^i + \frac{1}{12} \beta^i \partial_i ln \gamma \\
# \Rightarrow \partial_t \phi &= -\frac16 \alpha K + \frac16 \partial_i \beta^i + \frac{1}{12} \beta^i \partial_i ln \gamma \\
# \Rightarrow \partial_t \phi &= -\frac16 \alpha K + \frac16 \partial_i \beta^i + \frac{1}{12} \beta^i (\partial_i ln \gamma - \partial_i ln \eta) \\
# \Rightarrow \partial_t \phi &= -\frac16 \alpha K + \frac16 \partial_i \beta^i + \frac{1}{12} \beta^i \partial_i ln (\frac{\gamma}{\eta}) \\
# \Rightarrow \partial_t \phi &= -\frac16 \alpha K + \frac16 \partial_i \beta^i +  \beta^i \partial_i \phi \\
# \end{align}
# $$
#
# And that's one of the BSSN equations derived!

# %% [markdown]
# ROUND 2: 11.36, evolution of K.
#
# $$ \partial_t K = -\gamma^{ij} D_jD_i\alpha + \alpha(\tilde{A}_{ij} \tilde{A}^{ij} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^i \partial_i K $$

# %% [markdown]
# Of interest is 2.137.
#
# $$ \partial_t K = -D^2 \alpha + \alpha K_{ij}K^{ij} + 4\pi\alpha(\rho+S) + \beta^i D_i K $$

# %% [markdown]
# Rather quickly we can get almost all the terms to match, no weird form adjustments here.
#
# $$ \Rightarrow \partial_t K = -\gamma^{ij}D_jD_i \alpha + \alpha K_{ij}K^{ij} + 4\pi\alpha(\rho+S) + \beta^i \partial_i K $$
#
# The last term introduces no Christoffels as K is a scalar.

# %% [markdown]
# Note that this means the only term that isn't in the new form is $\alpha K_{ij} K^{ij}$.
#
# Unfortunately the terms we need to get it into are not in K, so this is going to be a little funky. 11.34 does give us the definition for our mysterious variable, though.
#
# $$ \tilde{A}_{ij} = e^{-4\phi} A_{ij} $$
#
# But what is this A? Well, it's not the EM potential, it's something else derived in the not-done **Chapter 3**. We hope this will not lead to issues down the line. The relation is 3.31.
#
# $$ K_{ij} = A_{ij} + \frac13 \gamma_{ij} K $$
#
# So now we have the tools to start the transformation.

# %% [markdown]
# $$
# \begin{align}
# \alpha K_{ij}K^{ij} &= \alpha(A_{ij} + \frac13 \gamma_{ij} K)(A^{ij} + \frac13 \gamma_{ij} K ) \\
# &= \alpha(A_{ij}A^{ij}  + \frac13 A_{ij} \gamma^{ij} K + \frac13 A^{ij}\gamma_{ij} K + \frac19 \gamma^{ij} \gamma_{ij} K^2) \\
# \end{align}
# $$

# %% [markdown]
# Now this is where we need to be careful. $\gamma^{ij}K_{ij} = K^i_i = K$ BUT $\gamma^{ij} \gamma_{ij} = \gamma^i_j \neq \gamma$. THIS NOTATION DROVE US NUTS. K is the TRACE. $\gamma$ is the DETERMINANT. Now, we don't know what the trace $\gamma$ is (wait, actually we do, it's $\delta^i_i$, but let's not worry about that for now), but we will know $\bar\gamma$'s, as its determinant is 1, it's a flat metric, and it's 3D... it will be 3.
#
# Also we note that A is, by definition, traceless, so the middle terms vanish.
#
# $$ = \alpha(A_{ij}A^{ij} + \frac19 \gamma^{ij} \gamma_{ij} K^2) $$
#
# Adjust to conformal terms.
#
# $$ = \alpha(\tilde A_{ij}\tilde A^{ij} + \frac19 \bar\gamma^{ij} \bar\gamma_{ij} K^2) $$
#
# Note the complete lack of additional factors added here. In fact, we're basically done! However, as we missed this step the first time, we will neet to justify why it works. And it's all because $\gamma^i_i = \bar\gamma^i_i = 3$. This means that $\bar\gamma^{ij}$ has to be the inverse of $\bar\gamma_{ij}$ and that the coefficeints on them have to vanish. Thus...
#
# $$ \bar\gamma_{ij} = e^{-4\phi}\gamma_{ij} \rightarrow \bar\gamma^{ij} = e^{4\phi}\gamma^{ij} $$
#
# Which means we extract exponentials of opposite exponente sign when we transform them. Thus, when transforming an up and a down, we get zero! (This also applies to the A terms, which is validated on 387.)
#
# As we discussed, the trace of $\bar\gamma$ is 3.
#
# $$ = \alpha( \tilde A_{ij}\tilde A^{ij} + \frac13 K^2) $$
#
# And now we have proven that all terms are correct!

# %% [markdown]
# ROUND 3: 11.37, evolution of the conformal metric $\bar\gamma_{ij}$
#
# $$ \partial_t \bar\gamma_{ij} = -2\alpha \tilde A_{ij} + \beta^k \partial_k \bar\gamma_{ij} + \bar\gamma_{ik} \partial_j \beta^k + \bar\gamma_{kj} \partial_i \beta^k - \frac23 \bar\gamma_{ij} \partial_k \beta^k $$

# %% [markdown]
# 11.7 is the relevant one here,
# $$\partial_t \gamma_{ij} = -2\alpha K_{ij} + D_i \beta_j + D_j \beta_i$$

# %% [markdown]
# And our result from ROUND 1
#
# $$\partial_t \phi = -\frac16 \alpha K + \beta^i \partial_i \phi + \frac16 \partial_i \beta^i$$

# %% [markdown]
# So this is a rather odd series of algebraic steps, but once again we use $\color{green}{colors}$ to indicate when we've gotten one of the terms we need. To make it even easier, cancelations will be $\color{red}{red}$Instead of something crazy, though, we simply start with...
#
# $$
# \begin{align}
# \partial_t \bar\gamma_{ij} &= \partial_t e^{-4\phi} \gamma_{ij} \\
# &= e^{-4\phi} \partial_t \gamma_{ij} + \gamma_{ij} \partial_t e^{-4\phi} \\
# &= e^{-4\phi} \partial_t \gamma_{ij} -4 \gamma_{ij} e^{-4\phi} \partial_t \phi \\
# &= e^{-4\phi} (-2\alpha K_{ij} + D_i \beta_j + D_j \beta_i) -4 \gamma_{ij} e^{-4\phi} (-\frac16 \alpha K + \beta^k \partial_k \phi + \frac16 \partial_k \beta^k) \\
# &= -2e^{-4\phi}\alpha K_{ij} + e^{-4\phi} D_i \beta_j +  e^{-4\phi}D_j \beta_i -4 \gamma_{ij} e^{-4\phi} (-\frac16 \alpha K + \beta^k \partial_k \phi + \frac16 \partial_k \beta^k) \\
# &= -2e^{-4\phi}\alpha A_{ij} -\color{red}{\frac23 e^{-4\phi}\gamma_{ij} \alpha K}  + e^{-4\phi} D_i \beta_j +  e^{-4\phi}D_j \beta_i  + \color{red}{\frac23 \gamma_{ij} e^{-4\phi} \alpha K} - 4 \gamma_{ij} e^{-4\phi} \beta^k \partial_k \phi - \frac23 \gamma_{ij} e^{-4\phi} \partial_k \beta^k \\
# &= \color{green}{-2\alpha \tilde A_{ij}} + e^{-4\phi} D_i \beta_j +  e^{-4\phi}D_j \beta_i - 4 \gamma_{ij} e^{-4\phi} \beta^k \partial_k \phi \color{green}{- \frac23 \bar \gamma_{ij} \partial_k \beta^k} \\
# &= e^{-4\phi} \gamma^k_i \gamma^l_j \nabla_k \beta_l +  e^{-4\phi}\gamma^k_j \gamma^l_i \nabla_k \beta_l - 4 \bar \gamma_{ij} \beta^k \partial_k \phi\\
# &= e^{-4\phi} \gamma^l_j \nabla_i (\gamma_{lk}\beta^k) +  e^{-4\phi}\gamma^l_i \nabla_j (\gamma_{lk}\beta^k) - 4 \bar \gamma_{ij} \beta^k \partial_k \phi\\
# &= \bar \gamma_{kj} \nabla_i \beta^k + \bar \gamma_{ki} \nabla_j \beta^k - 4 \bar \gamma_{ij} \beta^k \partial_k \phi\\
# &= \color{green}{\bar \gamma_{kj} \partial_i \beta^k + \bar \gamma_{ki} \partial_j \beta^k} + \bar \gamma_{kj} \beta^l \Gamma^k_{li} + \bar \gamma_{ki} \beta^l \Gamma^k_{lj} - 4 \bar \gamma_{ij} \beta^k \partial_k \phi\\
# &= + \bar \gamma_{kj} \beta^l \Gamma^k_{li} + \bar \gamma_{ki} \beta^l \Gamma^k_{lj} - 4 \bar \gamma_{ij} \beta^k \partial_k \phi\\
# &= + \bar \gamma_{kj} \beta^l \Gamma^k_{li} + \bar \gamma_{ki} \beta^l \Gamma^k_{lj} - 4 e^{-4\phi} \gamma_{ij} \beta^k \partial_k \phi\\
# &= + \bar \gamma_{kj} \beta^l \Gamma^k_{li} + \bar \gamma_{ki} \beta^l \Gamma^k_{lj} + \gamma_{ij} \beta^k \partial_k e^{-4\phi}\\
# &= + \bar \gamma_{kj} \beta^l \Gamma^k_{li} + \bar \gamma_{ki} \beta^l \Gamma^k_{lj} + \beta^k \partial_k (\gamma_{ij} e^{-4\phi}) - e^{-4\phi} \beta^k \partial_k \gamma_{ij} \\
# &= + \bar \gamma_{kj} \beta^l \Gamma^k_{li} + \bar \gamma_{ki} \beta^l \Gamma^k_{lj} + \color{green}{\beta^k \partial_k \bar\gamma_{ij}} - e^{-4\phi} \beta^k D_k \gamma_{ij} - e^{-4\phi} \beta^k \gamma_{lj}\Gamma^l_{ki} - e^{-4\phi} \beta^k \gamma_{li} \Gamma^l_{kj} \\
# &= + \bar \gamma_{kj} \beta^l \Gamma^k_{li} + \bar \gamma_{ki} \beta^l \Gamma^k_{lj} - \beta^k \bar\gamma_{lj}\Gamma^l_{ki} - \beta^k \bar\gamma_{li} \Gamma^l_{kj} \\
# &= + \bar \gamma_{kj} \beta^l \Gamma^k_{li} + \bar \gamma_{ki} \beta^l \Gamma^k_{lj} - \bar \gamma_{kj} \beta^l \Gamma^k_{li} - \bar \gamma_{ki} \beta^l \Gamma^k_{lj} \\
# &= 0 (\color{green}{+\text{CorrectTerms}})\\
# \end{align}
# $$

# %% [markdown]
# Okay so every step here should be evident, but some of the reasoning behind it is rather weird. We originally sought to show that all the Christoffels individually went to zero. This apperas to not be the case, which is why two Christoffel terms just... sit there in the last several steps. Now we KNEW they needed to cancel, so the entire purpose of manipulating the other side was to get Christoffels out of it that could also go to zero.
#
# The leftmost term rathe reasily transformed into the last term we needed in the answer, but the issue is it left a partial derivative behind, which is usually considered the simplest form. We could not say the partial derivative of the spatial metric could go to zero... but we DID know that $D_k \gamma_{ij} =0$! So the trick was to turn the partial into a covariant, which pops out *Christoffels*. Christoffels that can be transformed to the exact same format as the original ones. Yeah!

# %% [markdown]
# Thus, we FINALLY have all the terms we need. ROUND 3 victory!

# %% [markdown]
# ROUND 4: 11.38, evolution of the conformal traceless portion of the extrinsic curvature (wow, that's a mouthful.)
#
# $$ \partial_t \tilde A_{ij} = e^{-4\phi} \left( -(D_i D_j \alpha)^{TF} + \alpha(R_{ij}^{TF} - 8\pi S^{TF}_{ij}) \right) + \alpha(K\tilde A_{ij} - 2\tilde A_{il} \tilde A^l_j) + \beta^k\partial_k \tilde A_{ij} + \tilde A_{ik} \partial_j \beta^k + \tilde A_{kj} \partial_i \beta^k - \frac23 \tilde A_{ij} \partial_k \beta^k $$
#
# The TF is concerning. It means "trace free" version. The relation given for it is $R_{ij}^{TF} = R_{ij} - \gamma_{ij}\frac R3$. In order to make this clear let's explicitly expand it.

# %% [markdown]
# $$ \partial_t \tilde A_{ij} = e^{-4\phi} \left( -D_i D_j \alpha+\frac13 \gamma_{ij} D^2\alpha + \alpha R_{ij} - \alpha \frac13 \gamma_{ij} R - 8\pi \alpha S_{ij} + \frac83 \pi \alpha \gamma_{ij} S \right) + \alpha(K\tilde A_{ij} - 2\tilde A_{il} \tilde A^l_j) + \beta^k\partial_k \tilde A_{ij} + \tilde A_{ik} \partial_j \beta^k + \tilde A_{kj} \partial_i \beta^k - \frac23 \tilde A_{ij} \partial_k \beta^k $$

# %% [markdown]
# For the record, here are the terms we have not solved yet. This is just for reference.
#
# None! It's just that the junk isn't going away.

# %% [markdown]
# Today, our relavant equation is 11.8
#
# $$ \partial_t K_{ij} = \alpha(R_{ij} - 2K_{ik} K^k_j + KK_{ij}) - D_iD_j\alpha - 8\pi\alpha(S_{ij}-\frac12 \gamma_{ij}(S-\rho)) + \beta^k \partial_k K_{ij} + K_{ik}\partial_j\beta^k + K_{kj} \partial_i \beta^k $$
#
# As well as our result from ROUND 2
#
# $$ \partial_t K = -\gamma^{ij} D_jD_i\alpha + \alpha(\tilde{A}_{ij} \tilde{A}^{ij} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^i \partial_i K $$
#
# Turns out we also need all the others...
#
# $$\partial_t \gamma_{ij} = -2\alpha K_{ij} + D_i \beta_j + D_j \beta_i$$
#
# $$\partial_t \phi = -\frac16 \alpha K + \beta^i \partial_i \phi + \frac16 \partial_i \beta^i$$
#
# Using $\gamma_{ij}$ instead of $\bar\gamma_{i}j$ actually simplifies things, it appears, despite the fact that it makes there be five terms instead of four, two of thsoe five terms can immediately be combined into a useful form.

# %% [markdown]
# Trying to do this the same way as ROUND 3 didn't go well, so we attempt to follow the (somewhat dubious) suggestion of just subtracting the equations from each other in the following manner:
#
# $$ \partial_t \tilde A_{ij} = \partial_t (e^{-4\phi}A_{ij}) = \partial_t (e^{-4\phi}K_{ij} - e^{-4\phi}\frac13 \gamma_{ij} K) $$

# %% [markdown]
# See, the subtraction is going to have a bunch of extra terms. However, we will try to force it. The second term can absorb the conformal factor, but the first cannot and will have to split.
#
# $$ =  e^{-4\phi}\partial_tK_{ij} + K_{ij}\partial_te^{-4\phi} - \frac13 \partial_t(\bar\gamma_{ij} K) $$
# $$ =  e^{-4\phi}\partial_tK_{ij} + K_{ij}\partial_te^{-4\phi} - \frac13 K\partial_t\bar\gamma_{ij} - \frac13\bar\gamma_{ij}\partial_tK $$
#
# Okay so maybe absorbing the conformal factor was a bad idea.
#
# $$ =  e^{-4\phi}\partial_tK_{ij} + K_{ij}\partial_te^{-4\phi} - \frac13 Ke^{-4\phi}\partial_t\gamma_{ij} - \frac13 K\gamma_{ij}\partial_te^{-4\phi} - \frac13\bar\gamma_{ij}\partial_tK $$
#
# And wouldn't you know it, the $\partial_t \phi$ terms can be combined.
#
# $$ =  e^{-4\phi}\partial_tK_{ij} + A_{ij}\partial_te^{-4\phi} - \frac13 Ke^{-4\phi}\partial_t\gamma_{ij} - \frac13\bar\gamma_{ij}\partial_tK $$
#
# And take the derivative of the conformal factor so we can expand it.
#
# $$ =  e^{-4\phi}\partial_tK_{ij} -4 e^{-4\phi} A_{ij}\partial_t\phi - \frac13 Ke^{-4\phi}\partial_t\gamma_{ij} - \frac13\bar\gamma_{ij}\partial_tK $$
#
# $$ =  e^{-4\phi}\partial_tK_{ij} -4 \tilde A_{ij}\partial_t\phi - \frac13 Ke^{-4\phi}\partial_t\gamma_{ij} - \frac13\bar\gamma_{ij}\partial_tK $$

# %% [markdown]
# Anyway this means the subtractions and additions we have above need to be done directly, which will create this mess of an equation. ...It occurs to us that, ultimately, this is the same strategy as previously, just with a different way of going about it. Oh well, we're here now, might as well see it thhrough.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \\
# &+ e^{-4\phi}(\alpha(R_{ij} - 2K_{ik} K^k_j + KK_{ij}) - D_iD_j\alpha - 8\pi\alpha(S_{ij}-\frac12 \gamma_{ij}(S-\rho)) + \beta^k \partial_k K_{ij} + K_{ik}\partial_j\beta^k + K_{kj} \partial_i \beta^k)\\
# &-4\tilde A_{ij} (-\frac16 \alpha K + \beta^k \partial_k \phi + \frac16 \partial_k \beta^k)\\
# &-\frac13 K e^{-4\phi} (-2\alpha K_{ij} + D_i \beta_j + D_j \beta_i)\\
# &- \frac13 e^{-4\phi}\gamma_{ij}(-\gamma^{kl} D_kD_l\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^k \partial_k K ) \\
# \end{align}
# $$

# %% [markdown]
# Now, do we have any obviously correct terms? Yes, actually, a few. They are highlighted in green. (Note: the green terms are pulled out while the others are not, just in case the others have some trick that works better in the compressed form.)
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \\
# &+ \color{green}{e^{-4\phi}\alpha R_{ij}} - \color{green}{e^{-4\phi}D_iD_j\alpha} - \color{green}{e^{-4\phi} 8\pi \alpha S_{ij}}+ e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)) + \beta^k \partial_k K_{ij} + K_{ik}\partial_j\beta^k + K_{kj} \partial_i \beta^k)\\
# &-4\tilde A_{ij} (-\frac16 \alpha K + \beta^k \partial_k \phi + \frac16 \partial_k \beta^k)\\
# &-\frac13 K e^{-4\phi} (-2\alpha K_{ij} + D_i \beta_j + D_j \beta_i)\\
# &- \frac13 e^{-4\phi}\gamma_{ij}(-\gamma^{kl} D_kD_l\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^k \partial_k K ) \\
# \end{align}
# $$

# %% [markdown]
# Now, in line 4 we set the shift vectors to the k index by adding a metric in order to get the terms to match.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+ e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)) + \beta^k \partial_k K_{ij} + K_{ik}\partial_j\beta^k + K_{kj} \partial_i \beta^k)\\
# &-4e^{-4\phi} A_{ij} (-\frac16 \alpha K + \beta^k \partial_k \phi + \frac16 \partial_k \beta^k)\\
# &-\frac13 K e^{-4\phi} (-2\alpha K_{ij} + \gamma_{kj}D_i \beta^k + \gamma_{ki}D_j \beta^k)\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-\gamma^{kl} D_kD_l\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^k \partial_k K ) \\
# \end{align}
# $$

# %% [markdown]
# Extract the shift vector terms and move them to a new line from line 2 and 4.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+ e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)) + \beta^k \partial_k K_{ij})\\
# &-4e^{-4\phi} A_{ij} (-\frac16 \alpha K + \beta^k \partial_k \phi + \frac16 \partial_k \beta^k)\\
# &-\frac13 K e^{-4\phi} (-2\alpha K_{ij})\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-\gamma^{kl} D_kD_l\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^k \partial_k K ) \\
# &+e^{-4\phi} (K_{ik}\partial_j\beta^k + K_{kj} \partial_i \beta^k) -\frac13 K e^{-4\phi}(\gamma_{kj}D_i \beta^k + \gamma_{ki}D_j \beta^k) \\
# \end{align}
# $$

# %% [markdown]
# We should remember from ROUND 3 that the Christoffels do NOT vanish. However, we can still expand the spatial covariant derivatives.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+ e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)) + \beta^k \partial_k K_{ij})\\
# &-4e^{-4\phi} A_{ij} (-\frac16 \alpha K + \beta^k \partial_k \phi + \frac16 \partial_k \beta^k)\\
# &-\frac13 K e^{-4\phi} (-2\alpha K_{ij})\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-\gamma^{kl} D_kD_l\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^k \partial_k K ) \\
# &+e^{-4\phi} (K_{ik}\partial_j\beta^k + K_{kj} \partial_i \beta^k) -\frac13 K e^{-4\phi}(\gamma_{kj}\partial_i \beta^k + \gamma_{ki}\partial_j \beta^k) -\frac13 K e^{-4\phi}(\gamma_{kj}\beta^l \Gamma^k_{li} + \gamma_{ki}\beta^l \Gamma^k_{lj}) \\
# \end{align}
# $$

# %% [markdown]
# The curvatures can add to give us another set of A terms.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+ e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)) + \beta^k \partial_k K_{ij})\\
# &-4e^{-4\phi} A_{ij} (-\frac16 \alpha K + \beta^k \partial_k \phi + \frac16 \partial_k \beta^k)\\
# &-\frac13 K e^{-4\phi} (-2\alpha K_{ij})\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-\gamma^{kl} D_kD_l\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^k \partial_k K ) \\
# &+e^{-4\phi}A_{ik}\partial_j\beta^k + e^{-4\phi}A_{jk} \partial_i \beta^k -\frac13 K e^{-4\phi}(\gamma_{kj}\beta^l \Gamma^k_{li} + \gamma_{ki}\beta^l \Gamma^k_{lj}) \\
# \end{align}
# $$
#
# And if we apply the conformal factors...
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+ e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)) + \beta^k \partial_k K_{ij})\\
# &-4e^{-4\phi} A_{ij} (-\frac16 \alpha K + \beta^k \partial_k \phi + \frac16 \partial_k \beta^k)\\
# &-\frac13 K e^{-4\phi} (-2\alpha K_{ij})\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-\gamma^{kl} D_kD_l\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^k \partial_k K ) \\
# &+\color{green}{\tilde A_{ik}\partial_j\beta^k + \tilde A_{jk} \partial_i \beta^k} -\frac13 K e^{-4\phi}(\gamma_{kj}\beta^l \Gamma^k_{li} + \gamma_{ki}\beta^l \Gamma^k_{lj}) \\
# \end{align}
# $$

# %% [markdown]
# It occurs to us that we got so focused on extracting those terms we missed something: a correct term. we also simplify line 4, as it has been reduced to a single term, and adjust terms in lines 5 and 6.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+ e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)) + \beta^k \partial_k K_{ij})\\
# & - \color{green}{\frac23 \tilde A_{ij} \partial_k \beta^k} -4e^{-4\phi} A_{ij} (-\frac16 \alpha K + \beta^k \partial_k \phi) \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-D^2\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S) + \beta^k \partial_k K ) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} \\
# \end{align}
# $$

# %% [markdown]
# Lines 2, 3, and 5 have related last terms. Extract them.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+  e^{-4\phi}\beta^k \partial_k K_{ij} + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)))\\
# & -4e^{-4\phi} A_{ij}\beta^k \partial_k \phi -4e^{-4\phi} A_{ij} (-\frac16 \alpha K ) \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij}\beta^k \partial_k K  - \frac13 e^{-4\phi}\gamma_{ij} (-D^2\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} \\
# \end{align}
# $$

# %% [markdown]
# Move the terms to a new line. Revert the $\phi$ derivative into its more usable form.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)))\\
# & -4e^{-4\phi} A_{ij} (-\frac16 \alpha K ) \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-D^2\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} \\
# &+ e^{-4\phi}\beta^k \partial_k K_{ij} + A_{ij}\beta^k \partial_k e^{-4\phi} - \frac13 e^{-4\phi}\gamma_{ij}\beta^k \partial_k K \\
# \end{align}
# $$

# %% [markdown]
# So the new line there almost squishes into a term we need, but there's a pesky $\gamma_{ij}$ that we can't just move into the partial derivative. NOTE: does not work for $\bar\gamma_{ij}$ either. Not sure why, but it doesn't. However, we can still pull it off by using the fancy trick from ROUND 3 with an inverse product rule.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)))\\
# & -4e^{-4\phi} A_{ij} (-\frac16 \alpha K ) \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-D^2\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} \\
# &+ e^{-4\phi}\beta^k \partial_k K_{ij} + A_{ij}\beta^k \partial_k e^{-4\phi}  -  e^{-4\phi} \beta^k \partial_k(\frac13\gamma_{ij} K) + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$

# %% [markdown]
# The first and third terms can be combined.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)))\\
# & -4e^{-4\phi} A_{ij} (-\frac16 \alpha K ) \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-D^2\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} \\
# &+ e^{-4\phi}\beta^k \partial_k A_{ij} + A_{ij}\beta^k \partial_k e^{-4\phi} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$
#
# And now the first two terms can be combined via the product rule.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)))\\
# & -4e^{-4\phi} A_{ij} (-\frac16 \alpha K ) \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-D^2\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} \\
# &+ \color{green}{\beta^k \partial_k \tilde A_{ij}} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$

# %% [markdown]
# The remaining term is ugly, but it may be useful later. Let's move it up to the other line with the extra "junk" we have been accumulating. Maybe in the end we'll force some Christoffels out of it to cancel. Also, note that line 3 is one term, so let's simplify that.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)))\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (-D^2\alpha + \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$

# %% [markdown]
# Aha! There is another already correct term we missed! Extract it from line 5.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) +8\pi\alpha(\frac12 \gamma_{ij}(S-\rho)))\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &\color{green}{+ \frac13 e^{-4\phi}\gamma_{ij}D^2 \alpha} - \frac13 e^{-4\phi}\gamma_{ij} ( \alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha(\rho+S)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij}\\
# \end{align}
# $$

# %% [markdown]
# Now extract the S terms.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+4e^{-4\phi}\pi\alpha\gamma_{ij}S + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) -8\pi\alpha(\frac12 \gamma_{ij}\rho))\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &-\frac43e^{-4\phi}\pi\alpha\gamma_{ij}S - \frac13 e^{-4\phi}\gamma_{ij} (\alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha\rho) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$
#
# Combine the two S terms.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+\color{green}{\frac83e^{-4\phi}\pi\alpha\gamma_{ij}S} + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}) -8\pi\alpha(\frac12 \gamma_{ij}\rho))\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (\alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2) + 4\pi\alpha\rho) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$

# %% [markdown]
# Let's do the same with the $\rho$ terms, though it will not be as obvious what they combine to as we eventually need to relate it to R.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &- 4e^{-4\phi}\pi\alpha\gamma_{ij}\rho + e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}))\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac43 e^{-4\phi}\gamma_{ij} \pi\alpha\rho - \frac13 e^{-4\phi}\gamma_{ij} (\alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$
#
# Combine and put result on new line...
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+ e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}))\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (\alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# & - \frac{16}{3}e^{-4\phi}\pi\alpha\gamma_{ij}\rho
# \end{align}
# $$
#
# Now here's a fancy relation from MNR2.136: $ R + K^2 - K_{ij}K^{ij}= 16\pi\rho $. Not only will this give us the term we need, but it will also provide us other tools for the last few terms.

# %% [markdown]
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &+ e^{-4\phi}(\alpha(- 2K_{ik} K^k_j + KK_{ij}))\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij} (\alpha(\tilde{A}_{kl} \tilde{A}^{kl} + \frac13K^2)) \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# & - \color{green}{\frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}R} - \frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K^2 + \frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K_{kl}K^{kl} \\
# \end{align}
# $$

# %% [markdown]
# We think it is finally time to expand out the remaining terms, as we spy something that is about to cancel.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & - 2e^{-4\phi}\alpha K_{ik} K^k_j + e^{-4\phi}\alpha KK_{ij}\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij}\alpha\tilde{A}_{kl} \tilde{A}^{kl} + \frac19 e^{-4\phi}\gamma_{ij}\alpha K^2 \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# &- \frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K^2 + \frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K_{kl}K^{kl} \\
# \end{align}
# $$

# %% [markdown]
# A fun relation used earlier is that when you have two conformal objects that are inverse of each other, that means you can set them to non-conformal without changing anything.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & - 2e^{-4\phi}\alpha K_{ik} K^k_j + e^{-4\phi}\alpha KK_{ij}\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \frac13 e^{-4\phi}\gamma_{ij}\alpha{A}_{kl} {A}^{kl} + \frac19 e^{-4\phi}\gamma_{ij}\alpha K^2 \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# &- \frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K^2 + \frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K_{kl}K^{kl} \\
# \end{align}
# $$

# %% [markdown]
# Expand out the double-A term. Since $A_{ij}$ traceless, this only produces two terms.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & - 2e^{-4\phi}\alpha K_{ik} K^k_j + e^{-4\phi}\alpha KK_{ij}\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \color{red}{\frac13 e^{-4\phi}\gamma_{ij}\alpha{K}_{kl} {K}^{kl}} - \frac{1}{27} e^{-4\phi}\gamma_{ij}\alpha\gamma_{kl}\gamma^{kl}K^2 + \frac19 e^{-4\phi}\gamma_{ij}\alpha K^2 \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# &- \frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K^2 + \color{red}{\frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K_{kl}K^{kl}} \\
# \end{align}
# $$

# %% [markdown]
# What a nice cancel. On line 5 we're about to get another one from $\gamma_{kl}\gamma^{kl} = \gamma^l_l = 3$
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & - 2e^{-4\phi}\alpha K_{ik} K^k_j + e^{-4\phi}\alpha KK_{ij}\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &- \color{red}{\frac{1}{9} e^{-4\phi}\gamma_{ij}\alpha K^2 + \frac19 e^{-4\phi}\gamma_{ij}\alpha K^2} \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# &- \frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K^2 \\
# \end{align}
# $$

# %% [markdown]
# That removes an entire line! Yes! The queation is, now what? Well, we think we spy another term ripe for the taking, it's in line 2. Convert form K to A.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &- 2e^{-4\phi}\alpha K_{ik} K^k_j + e^{-4\phi}\alpha KA_{ij} + \color{red}{\frac13 e^{-4\phi}\alpha \gamma_{ij} K^2}\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# &- \color{red}{\frac{1}{3}e^{-4\phi}\alpha\gamma_{ij}K^2} \\
# \end{align}
# $$
#
# Oh hey, a cancellation, we were wondering where that was. Anyway, applying the conformal factor will get us another term.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &- 2e^{-4\phi}\alpha K_{ik} K^k_j + \color{green}{\alpha K\tilde A_{ij}}\\
# &+\frac23 e^{-4\phi} A_{ij} \alpha K  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$

# %% [markdown]
# This means we only have one term left to find! Then we can focus our efforts on proving all the "junk" goes to zero. Our hunch is that, somehow, lines 2 thorugh 4 all combine into our last term, and that line 5 is junk. Ah, but we have to get rid of the conformal factor somehow... ah, that's right, if the indices are mixed the conformal and ordinary versions are the same, so that extra tilde on the term we seek is just there to be annoying. Expand the term on line 3.
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# &- 2e^{-4\phi}\alpha K_{ik} K^k_j \\
# &+\frac23 e^{-4\phi} K_{ij} \alpha K - \frac29 e^{-4\phi} \gamma_{ij} \alpha K^2  \\
# &+\frac23 \alpha e^{-4\phi}K K_{ij}\\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$

# %% [markdown]
# Now this is a little hard to see, but those terms when combined do become the term we want. Here's the relation:
#
# $$ -2A_{ik}A^k_j = -2(K_{ik} - \frac13 \gamma_{ik} K)(K^k_j - \frac13 \gamma^k_j K) = -2K_{ik}K^k_j + \frac23 K_{ij} K + \frac23 K_{ij} K - \frac29 \gamma_{ij} K^2 $$
#
# And so...
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & -2\alpha e^{-4\phi} A_{ik} A^k_j \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$
#
# Remember if the indices are up and down, conformalizing is free! So we only apply the conformal factor once and...
#
# $$
# \begin{align}
# \partial_t \tilde A_{ij} &= \color{green}{C}\\
# & - \color{green}{2\alpha \tilde A_{ik} \tilde A^k_j} \\
# &-\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$

# %% [markdown]
# Which means we have, at long last, found EVERY term! All that's left to prove is that the remaining junk goes to nothing. This situation seems quite familiar...
#
# $$
# \begin{align}
# 0 = -\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# \end{align}
# $$
#
# Follow the method of ROUND 3!
#
# $$
# \begin{align}
# 0 &= -\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k \partial_k\gamma_{ij} \\
# &= -\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^k D_k\gamma_{ij} + \frac13 e^{-4\phi} K \beta^k \gamma_{lj} \Gamma^l_{ki} + \frac13 e^{-4\phi} K \beta^k \gamma_{li} \Gamma^l_{kj} \\
# &= -\frac13 K e^{-4\phi}\gamma_{kj}\beta^l \Gamma^k_{li} -\frac13 K e^{-4\phi}\gamma_{ki}\beta^l \Gamma^k_{lj} + \frac13 e^{-4\phi} K \beta^l \gamma_{kj} \Gamma^k_{li} + \frac13 e^{-4\phi} K \beta^l \gamma_{ki} \Gamma^k_{lj} \\
# &= 0 \\
# \end{align}
# $$
#
# YES!!!!!
#
# BEAUTIFUL!!!!
#
# VICTORY!!!

# %% [markdown]
# ![Dccyyy8V0AAqNqo.jpg](attachment:Dccyyy8V0AAqNqo.jpg)

# %% [markdown]
# One may ask: why did we not just delete the junk at the start if it self-canceled?
#
# Because we didn't realize it would do that. And we originally had the third term incorrect. But it's all good now!

# %% [markdown]
# ### ROUND 3 ALTERNATE
#
# Let's derive the evolution equation for the conformal metric. Reminders:
#
# \begin{align}
# \gamma_{ij} &= e^{4\phi}\bar\gamma_{ij}\;,\\
# A_{ij} &= K_{ij} - \frac{1}{3}K\gamma_{ij}\;,\\
# \tilde{A}_{ij} &= e^{-4\phi}A_{ij}\;.
# \end{align}
#
# a) Show that
#
# $$
# \Gamma_{ijk} + \Gamma_{jik} = \partial_{k}\gamma_{ij}\;,
# $$
#
# where $\Gamma_{lij} = \gamma_{lk}\Gamma^{k}_{\ ij}$ and $\Gamma^{k}_{\ ij}$ are the Christoffel symbols associated with $\gamma_{ij}$.
#
# b) The evolution equation of the physical spatial metric $\gamma_{ij}$ is given by
#
# $$
# \partial_{t}\gamma_{ij} = -2\alpha K_{ij} + D_{i}\beta_{j} + D_{j}\beta_{i}\;.
# $$
#
# Expand the covariant derivatives of the shift vector and use the result from item a to show that
#
# $$
# \partial_{t}\gamma_{ij} = \beta^{k}\partial_{k}\gamma_{ij} - 2\alpha K_{ij} + \gamma_{jk}\partial_{i}\beta^{k} + \gamma_{ik}\partial_{j}\beta^{k}\;.
# $$
#
# c) Starting from $\partial_{t}\bar\gamma_{ij} = \partial_{t}\left(e^{-4\phi}\gamma_{ij}\right)$ and using the result from item b, as well as the evolution equation for the conformal exponent,
#
# $$
# \partial_{t}\phi = -\frac{1}{6} \alpha K + \beta^{k} \partial_{k} \phi + \frac{1}{6} \partial_{k} \beta^{k}\;,
# $$
#
# show that
#
# $$
# \partial_{t}\bar\gamma_{ij} = \beta^{k}\partial_{k}\bar\gamma_{ij} -2\alpha\tilde{A}_{ij} + \bar\gamma_{jk}\partial_{i}\beta^{k} + \bar\gamma_{ik}\partial_{j}\beta^{k} - \frac{2}{3}\bar g $$

# %% [markdown]
# **check to make sure above question is formulated correctly before digging in**

# %% [markdown]
# <a id='P3'></a>
#
# # Problem 3 \[Back to [top](#toc)\]
# $$\label{P3}$$
#
# *Show that the shift terms in 11.43 arise from the Lie derivative of $\bar\Gamma^i$ along $\beta^i$*
#
# $$ \mathcal{L}_\beta \bar\Gamma^i = \beta^j \partial_j \bar\Gamma^j \partial_j \beta^i + \frac23 \bar\Gamma^i \partial_j \beta^j + \frac13 \bar\gamma^{li}\partial_l \partial_j \beta^j + \bar\gamma^{lj}\partial_j\partial_l\beta^i $$
#
# *Hint: first show that the conformal connection coefficients transform according to*
#
# $$ \bar\Gamma^{a'} = J^{-W} \frac{\partial x^{a'}}{\partial x^b}\bar\Gamma^b + J^{-W}\bar\gamma^{ij} \frac{\partial x^{b'}}{\partial x^i}\frac{\partial x^{c'}}{\partial x^j}\frac{\partial x^{a'}}{\partial x^l}\frac{\partial^2 x^l}{\partial x^{b'}x^{c'}}-\frac12 J^{-W} \bar\gamma^{bc}\frac{\partial x^{a'}}{\partial x^{b}}\partial_c(lnJ^W) $$
#
# ((Oh my goodness how horrifying))
#
# *where J is the Jacobian of the transformation and W is the weight of $\bar\gamma_{ij}$. The first term is the usual transformation term for a tensor (except for the Jacobian factor), the second term arises because the connection coefficients do not transform like tensors, and the third term appears because $\bar\gamma_{ij}$ is a tensor density. Then use A.7 to find equaiton 11.44* ((The goal for the first part)) *for W = -2/3. (cf. equations A.36 and A.37)*

# %% [markdown]
# ABANDONED: Leo pointed out that this was a lot of work for little reward. Skipped. Not "necessary" for where I'm at.

# %% [markdown]
# 11.40 gives us the definition of $\bar\Gamma$
#
# $$ \bar\Gamma^i = \bar\gamma^{jk}\bar\Gamma^i_{jk} = -\partial_t \bar\gamma^{ij} $$

# %% [markdown]
# Assume that $\bar\Gamma^i$ is neither a Tensor NOR a Tensor Density, so we can't just up and apply A.37.
#
# $$ \mathcal{L}_X T^a_b = X^c \partial_c T^a_b - T^c_b \partial_c X^a + T^a_c \partial_bX^c + WT^a_b\partial_c X^c  $$

# %% [markdown]
# As such we split up the conformal connection coefficients its constituent parts.
#
# $$ \mathcal{L}_\beta \bar\Gamma^i = - \mathcal{L}_\beta (\partial_t \bar\gamma^{ij}) $$
#
# Now thsi can be evaluated, because we are told $\bar\gamma_{ij}$ is a tensor density with weight -2/3. The question is, does the weight remain the same when the indices are up or down? Let's assume it does. In that case, our result is...
#
# $$ -\mathcal{L}_\beta (\partial_t \bar\gamma^{ij}) = -\beta^k \partial_k (\partial_t \bar\gamma^{ij})  + (\partial_t \bar\gamma^{kj})  \partial_k \beta^i + (\partial_t \bar\gamma^{ik})  \partial_k\beta^j - W(\partial_t \bar\gamma^{ij}) \partial_k \beta^k  $$
#
# And with W - -2/3...
#
# $$ \mathcal{L}_\beta \bar\Gamma^i = -\beta^k \partial_k (\partial_t \bar\gamma^{ij})  + (\partial_t \bar\gamma^{kj})  \partial_k \beta^i + (\partial_t \bar\gamma^{ik})  \partial_k\beta^j + \color{green}{\frac23 (\bar\Gamma^i) \partial_j \beta^j}  $$
#
# How nice, there's a term we need. In theory, the others should be able to be derived from the other equations. Since everything is a time derivative of the conformal metric, well, we happen to HAVE that equation.
#
# $$ \partial_t \bar\gamma_{ij} = -2\alpha \tilde A_{ij} + \beta^k \partial_k \bar\gamma_{ij} + \bar\gamma_{ik} \partial_j \beta^k + \bar\gamma_{kj} \partial_i \beta^k - \frac23 \bar\gamma_{ij} \partial_k \beta^k $$
#
# Now comes the annoying part of flipping the indices... except it's not annoying because $\bar\gamma$ is the flat metric! Its up and down indices are equal to each other! Thus, moving the indices up without any operations is fine, as every component needs to be the exact same.
#
# $$ \partial_t \bar\gamma^{ij} = -2\alpha \tilde A^{ij} + \beta^k \partial_k \bar\gamma^{ij} + \bar\gamma^i_k \partial^j \beta^k + \bar\gamma_k^j \partial^i \beta^k - \frac23 \bar\gamma^{ij} \partial_k \beta^k $$

# %% [markdown]
# The issue here that we need to remember is that the Christoffels are NOT tensors, and thus the rules we've come to depend on no longer apply. But the appendix will give us some help, as it tells us how to deal with these quantities... well at least it seems that way, we'll have to play around a bit to see the actual truth of the matter. What we actually want to start with is A.37, the definition of the Lie derivative for tensor densities.
#
# $$ \mathcal{L}_X T^a_b = X^c \partial_c T^a_b - T^c_b \partial_c X^a + T^a_c \partial_bX^c + WT^a_b\partial_c X^c  $$
#
# So for OUR situation this translates to
#
# $$ \mathcal{L}_\beta \bar\Gamma^i = \beta^c \partial_c \bar\Gamma^i - \bar\Gamma^c \partial_c \beta^i + W\bar\Gamma^i\partial_c \beta^c  $$
#
# We note that 4D indices do not apply today.
#
# $$ \mathcal{L}_\beta \bar\Gamma^i = \beta^j \partial_j \bar\Gamma^i - \bar\Gamma^j \partial_j \beta^i + W\bar\Gamma^i\partial_j \beta^j  $$
#
# We are actually given the mysterious W, 2/3.
#
# $$ \mathcal{L}_\beta \bar\Gamma^i = \beta^j \partial_j \bar\Gamma^i - \bar\Gamma^j \partial_j \beta^i - \frac23 \bar\Gamma^i\partial_j \beta^j  $$

# %% [markdown]
# That last term LOOKS like it would be right, but alas, it is the wrong sign. So we are unsure where we are.

# %% [markdown]
# <a id='P4'></a>
#
# # Problem 4 \[Back to [top](#toc)\]
# $$\label{P4}$$
#
# *Show that in the system 11.4, 11.17, and 11.18 constraint violations measured by the parameter $\mathcal{C}$ defined in 11.56 satisfy the wave equation*
#
# $$ (-\partial^2_t + a^2 D_i D^i)\mathcal{C} = 0 $$

# %% [markdown]
# 11.4: $\partial_t A_i = -E_i - D_i\Phi$
#
# 11.17: $\partial_t \Gamma = \partial_t D^i A_i = D^i \partial_t A_i = -D^i E_i - D_i D^i \Phi = -D_iD^i \Phi - 4\pi\rho_e$
#
# 11.18: $\partial_t E_i = -D_jD^j A_i + D_i \Gamma - 4\pi j_i$
#
# And our paramater...
#
# $$ \mathcal{C} = D^i E_i - 4\pi \rho_e $$

# %% [markdown]
# Let's just write it out and see where we end up.
#
# $$
# \begin{align}
# &= -\partial_t^2 \mathcal{C} + a^2 D_i D^i \mathcal{C} \\
# &= -\partial_t^2 D^i E_i + \partial_t^2(4\pi\rho)  + a^2 D_i D^i D^j E_j - a^2 D_i D^i (4\pi \rho_e) \\
# &= -\partial_t \partial_t D^i E_i + 4\pi \partial_t^2\rho  + a^2 D_i D^i D^j E_j - a^2 D_i D^i \partial_t \Gamma - a^2 D_i D^i D_j D^j \Phi \\
# &= -\partial_t D^i \partial_t E_i + 4\pi \partial_t^2\rho  + a^2 D_i D^i D^j E_j - a^2 D_i D^i \partial_t \Gamma - a^2 D_i D^i D_j D^j \Phi \\
# &= \partial_t D^i D_j D^j A_i -\partial_t D^i D_i \Gamma +\partial_t D^i(4\pi j_i) + 4\pi \partial_t^2\rho  + a^2 D_i D^i D^j E_j - a^2 D_i D^i \partial_t \Gamma - a^2 D_i D^i D_j D^j \Phi \\
# \end{align}
# $$

# %% [markdown]
# $$
# \begin{align}
# &= -\partial_t^2 \mathcal{C} + a^2 D_i D^i \mathcal{C} \\
# &= \partial_t (4\pi(D^ij_i + \partial_t \rho_e)) + a^2 D_i D^i D^j E_j - a^2 D_i D^i (4\pi \rho_e) \\
# &= 4\pi\partial_tD^ij_i + 4\pi\partial_t^2 \rho_e + a^2 D_i D^i (4\pi\rho_e) - a^2 D_i D^i (4\pi \rho_e) \\
# &= 4\pi\partial_tD^ij_i + 4\pi\partial_t^2 \rho_e \\
# \end{align}
# $$
#
# We know the first temporal derivative goes to zero, but not neceassarily the second, we have to show that.

# %% [markdown]
# $$
# \begin{align}
# &= \partial_t D^i(4\pi j_i) + 4\pi\partial_t^2 \rho_e \\
# &= \partial_t D^i (-\partial_t E_i + D_jD^jA_i - D_i \Gamma)+ 4\pi\partial_t^2 \rho_e \\
# &= - \partial^2_t D^i E_i + \partial_t D^i D_j D^j A_i - D^i D_i \Gamma + 4\pi\partial_t^2 \rho_e \\
# &= - \partial^2_t (4\pi \rho_e) + D_j D^j \partial_t D^i A_i - \partial_t D^i D_i \Gamma + 4\pi\partial_t^2 \rho_e \\
# &= D_j D^j \partial_t \Gamma - D^i D_i \partial_t \Gamma \\
# &=0 \\
# \end{align}
# $$
#
# Which is what we sought to show.

# %% [markdown]
# <a id='latex_pdf_output'></a>
#
# # Addendum: Output this notebook to $\LaTeX$-formatted PDF file \[Back to [top](#toc)\]
# $$\label{latex_pdf_output}$$
#
# The following code cell converts this Jupyter notebook into a proper, clickable $\LaTeX$-formatted PDF file. After the cell is successfully run, the generated PDF may be found in the root NRPy+ tutorial directory, with filename
# [MNR-02.pdf](MNR-02.pdf) (Note that clicking on this link may not work; you may need to open the PDF file through another means.)
#
# **Important Note**: Make sure that the file name is right in all six locations, two here in the Markdown, four in the code below.
#
# * MNR-02.pdf
# * MNR-02.ipynb
# * MNR-02.tex

# %%
import cmdline_helper as cmd    # NRPy+: Multi-platform Python command-line interface
cmd.output_Jupyter_notebook_to_LaTeXed_PDF("MNR-02")
# Out:
# Created MNR-02.tex, and compiled LaTeX file to PDF file MNR-02.pdf
