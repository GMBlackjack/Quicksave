# %% [markdown]
# # Electromagnetics Homework 01: Dots and Crosses
#
# ## Gabriel M Steward
#
# ### August 2022

# %% [markdown]
# <a id='toc'></a>
#
# # Table of Contents
# $$\label{toc}$$
#
# [Problem 1](#P1) (Charge Conservation on Sheets)
#
# [Problem 2](#P2) (Fields Around Time-varying Currents)
#
# [Problem 3](#P3) (The Coloumb and Biot-Savart Laws)
#
# [PDF](#latex_pdf_output) (turn this into a PDF)

# %% [markdown]
# <a id='P1'></a>
#
# # Problem 1 \[Back to [top](#toc)\]
# $$\label{P1}$$
#
# *A surface current density $\textbf K(x,y,t)$ flows in the z=0 plane. Compute the charge density $\sigma(x,y,t)$ on the plane assuming the plane is completley uncharged at t=0 when $\textbf K(x,y,t)$ has each of the following forms. Comment on whether the charge density depends on the polar coordinates $\rho$ and $\phi$ in each case. You might want to sketch the currents to see whether these trends make sense.*
#
# *a)* $\textbf K(x,y,t) = K_0  \frac yR \hat x + K_0 \frac xR \hat y$

# %% [markdown]
# First of all, we see that $\mathcal K$ is constant in time, so it's always the same, but the charge density need not be. We have, from the lecture notes, the general continuity equation:
#
# $$ \frac{\partial \rho}{\partial t} + \nabla \cdot \textbf j = 0$$
#
# Which can be easily converted into the 2D version
#
# $$ \frac{\partial \sigma}{\partial t} + \nabla \cdot \textbf K = 0$$
#
# Now the method becomes obvious. We have $\textbf K$ and can calculate its divergence, which allows us to solve for the derivative of the charge density. The boundary condition on the charge density (t=0, $\sigma$=0), will give us what we need to find the integration constant for the actual charge density. This procedure should work for all parts of this problem.

# %% [markdown]
# So let's apply it to a). The divergence of $\mathcal K$ is... zero. The divergence takes the derivatives of the variables in the same direction as they are, so for instance we take the x derivative of $K_0 y/R$ which is zero. The same goes for the y component. Thus...
#
# $$ \frac{\partial \sigma}{\partial t} + 0 = 0$$
# $$ \Rightarrow \sigma = C$$
#
# Now, since $\sigma$ has to be a constant and we have a boundary condition that sets it to 0 at t=0, clearly it has to be zero.
#
# $$ \sigma(x,y,t) = 0 $$
#
# This quite obviously does not depend on any coordinates at all, much less the polar ones.

# %% [markdown]
# Here is the vector field representation of $\textbf K$ by the way, made with the Geogebra Applet https://www.geogebra.org/m/cXgNb58T by Juan Carlos Ponce Campuzano
#
# ![VectorField1.jpg](attachment:VectorField1.jpg)
#
# Trying to think of this physically... this is more than a little confusing. It looks like charge should be taken from one place and moved to another. Sure, in our situation where everything is zero, this is fine. But if the charge density was a constant it sure looks like two quadrants would lose charge over time and the other two would gain it.

# %% [markdown]
# *b)* $\textbf K(x,y,t) = K_0  \frac xR \hat x + K_0 \frac yR \hat y$

# %% [markdown]
# Now this might be more illuminating, as not everything vanishes. The divergence of $\textbf K$ is now $\frac{K_0}{R} + \frac{K_0}{R} = \frac{2K_0}{R}$, as the derivative removes the variable from the respective component. Thus, we now have:
#
# $$ \frac{\partial \sigma}{\partial t} = -\frac{2K_0}{R} $$
#
# Now the right hand side is a constant, not zero, so when we integrate both sides we actually get something.
#
# $$ \sigma = -\frac{2K_0t}{R} + C $$
#
# Now, with our boundary condition at t=0, this means that C has to be 0. Therefore...
#
# $$ \sigma = -\frac{2K_0t}{R} + C $$
#
# Which, again, has no spatial coodrinate dependence--though this time we DO have a temporal dependence. The charge is slowly giong to rise.

# %% [markdown]
# The vector field representation is
#
# ![VectorField2.jpg](attachment:VectorField2.jpg)
#
# Now this one makes sense. More charge is forever appearing in the center of the plane and it spreads out through the rest of it. One would think that, since it's getting faster the further it gets away from the origin, it would be an uneven spread of charge, but that actually isn't the case. The "speed" (or magnitude) of the flow goes up as much as is needed to cover the greater area that exists out further away from the origin.

# %% [markdown]
# *c)* $\textbf K(x,y,t) = K_0  \frac{x}{\sqrt{x^2+y^2}} \hat x + K_0 \frac{y}{\sqrt{x^2+y^2}} \hat y$

# %% [markdown]
# *d)* $\textbf K(x,y,t) = K_0  \frac{y}{\sqrt{x^2+y^2}} \hat x + K_0 \frac{x}{\sqrt{x^2+y^2}} \hat y$

# %% [markdown]
# *e)* $\textbf K(x,y,t) = K_0  \frac{y}{\sqrt{x^2+y^2}} \hat x - K_0 \frac{x}{\sqrt{x^2+y^2}} \hat y$

# %% [markdown]
# <a id='P2'></a>
#
# # Problem 2 \[Back to [top](#toc)\]
# $$\label{P2}$$
#
# *a) An infinitely long cylindrical shell of radius R carries a spatially uniform but time-dependent solenoid-like surface current density $\textbf K(t) = K_0(t/\tau)\hat\phi$, where $K_0$ and $\tau$ are constants. Find the electric and magnetic fields everywhere in space. Hint: begin with a simple guess for the magnetic field outside the solenoid.*

# %% [markdown]
# This represents a current that flows in circles along the outside of a cylinder. Circular currents do indeed create magnetic fields.

# %% [markdown]
# *b) An infinitely long cylindrical shell of radius R carries a spatially uniform but time-dependent wire-like surface current density $\textbf K(t) = K_0 (t/\tau) \hat z$, where $K_0$ and $\tau$ are constants. Find the electric and magnetic fields everywhere in space. Hint: You may assume the electric field inside the cylinder is zero.*

# %% [markdown]
# This is a current moving "up" along a cylindrical shell. All electric influences in the interior of the shell go to zero, as is suggested by the problem. No magnetic fields will be created since there are no loops of current. (?)

# %% [markdown]
# <a id='P3'></a>
#
# # Problem 3 \[Back to [top](#toc)\]
# $$\label{P3}$$
#
# *The electric and magnetic fields for time-independent distributions of charge and current are:*
#
# $$ \textbf E(r) = \frac{1}{4\pi \epsilon_0} \int \rho(r') \frac{\textbf r - \textbf r'}{|\textbf r - \textbf r'|^3} d^3 r'  $$
#
# $$ \textbf B(r) = \frac{\mu_0}{4\pi} \int \textbf j(r') \times \frac{\textbf r - \textbf r'}{|\textbf r - \textbf r'|^3} d^3 r'  $$
#
# *a) calculate $\nabla \cdot \textbf E$ and $\nabla \times \textbf E$ and verify that these are consistent with Maxwell's equaitons.*

# %% [markdown]
# *b) calculate $\nabla \cdot \textbf B$ and $\nabla \times \textbf B$ and verify that these are consistent with Maxwell's equaitons. (Hint: for the curl equation you will need to uset he continuity equation, and it will take some effort to make that expression relevant).*

# %% [markdown]
# <a id='latex_pdf_output'></a>
#
# # Addendum: Output this notebook to $\LaTeX$-formatted PDF file \[Back to [top](#toc)\]
# $$\label{latex_pdf_output}$$
#
# The following code cell converts this Jupyter notebook into a proper, clickable $\LaTeX$-formatted PDF file. After the cell is successfully run, the generated PDF may be found in the root NRPy+ tutorial directory, with filename
# [MNR-02.pdf](MNR-02.pdf) (Note that clicking on this link may not work; you may need to open the PDF file through another means.)
#
# **Important Note**: Make sure that the file name is right in all six locations, two here in the Markdown, four in the code below.
#
# * MNR-02.pdf
# * MNR-02.ipynb
# * MNR-02.tex

# %%
import cmdline_helper as cmd    # NRPy+: Multi-platform Python command-line interface
cmd.output_Jupyter_notebook_to_LaTeXed_PDF("MNR-02")
# Out:
# Created MNR-02.tex, and compiled LaTeX file to PDF file MNR-02.pdf
